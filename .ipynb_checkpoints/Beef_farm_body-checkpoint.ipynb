# %%
import cv2
import numpy as np
import open3d as o3d
import json
import glob
import matplotlib.pyplot as plt
import copy
import teaserpp_python
from numpy.linalg import inv
from scipy.spatial import cKDTree
import time
from PIL import Image
import torchvision
import torch
from torchvision import transforms as T 
from torchvision.models.detection.faster_rcnn import FastRCNNPredictor
from torchvision.models.detection.mask_rcnn import MaskRCNNPredictor
from numba import jit, prange
import os
import csv 
# Load MaskRCNN 

import subprocess

globT = 0
def register_two_views_teaser(A_pcd_raw,B_pcd_raw,VOXEL_SIZE):
    
    VISUALIZE = True
    A_pcd = A_pcd_raw.voxel_down_sample(voxel_size=VOXEL_SIZE)
    B_pcd = B_pcd_raw.voxel_down_sample(voxel_size=VOXEL_SIZE)
    #if VISUALIZE:
     #   o3d.visualization.draw_geometries([A_pcd,B_pcd]) # plot downsampled A and B 

    A_xyz = pcd2xyz(A_pcd) # np array of size 3 by N
    B_xyz = pcd2xyz(B_pcd) # np array of size 3 by M

    print("Extracting FPFH features")
    # extract FPFH features
    A_feats = extract_fpfh(A_pcd,VOXEL_SIZE)
    B_feats = extract_fpfh(B_pcd,VOXEL_SIZE)
    print(A_feats.shape)
    print("Computing FPFH correspondences")
    # establish correspondences by nearest neighbour search in feature space
    corrs_A, corrs_B = find_correspondences(
        A_feats, B_feats, mutual_filter=True)
    A_corr = A_xyz[:,corrs_A] # np array of size 3 by num_corrs
    B_corr = B_xyz[:,corrs_B] # np array of size 3 by num_corrs

    num_corrs = A_corr.shape[1]
    print(f'FPFH generates {num_corrs} putative correspondences.')

    # visualize the point clouds together with feature correspondenc
    # robust global registration using TEASER++
    NOISE_BOUND = VOXEL_SIZE
    teaser_solver = get_teaser_solver(NOISE_BOUND)
    teaser_solver.solve(A_corr,B_corr)
    solution = teaser_solver.getSolution()
    R_teaser = solution.rotation
    t_teaser = solution.translation
    T_teaser = Rt2T(R_teaser,t_teaser)

    # Visualize the registration results
    A_pcd_T_teaser = copy.deepcopy(A_pcd).transform(T_teaser)
    #o3d.visualization.draw_geometries([A_pcd_T_teaser,B_pcd])

    # local refinement using ICP
    icp_sol = o3d.pipelines.registration.registration_icp(
          A_pcd, B_pcd, NOISE_BOUND, T_teaser,
          o3d.pipelines.registration.TransformationEstimationPointToPoint(),
          o3d.pipelines.registration.ICPConvergenceCriteria(max_iteration=100))
    T_icp = icp_sol.transformation
    
#     T_cicp = colored_ICP_teaser(A_pcd, B_pcd, T_teaser)
    
#     # visualize the registration after COLORED ICP refinement
#     A_pcd_T_cicp = copy.deepcopy(A_pcd).transform(T_cicp)
#     if VISUALIZE:
#         Acopy = copy.deepcopy(A_pcd_T_cicp).paint_uniform_color([0.0,0.0,1])
#         Bcopy = copy.deepcopy(B_pcd).paint_uniform_color([1.0,0.0,0.0])
#         o3d.visualization.draw_geometries([Acopy,Bcopy])
    

    # visualize the registration after ICP refinement
    A_pcd_T_icp = copy.deepcopy(A_pcd).transform(T_icp)
    if VISUALIZE:
        Acopy = copy.deepcopy(A_pcd_T_icp).paint_uniform_color([0.0,0.0,1])
        Bcopy = copy.deepcopy(B_pcd).paint_uniform_color([1.0,0.0,0.0])
        o3d.visualization.draw_geometries([Acopy,Bcopy])
    tformed_A = copy.deepcopy(A_pcd_raw).transform(T_icp)
    res = o3d.geometry.PointCloud()
    res = tformed_A + B_pcd_raw
    
    return res,T_icp

def pcd2xyz(pcd):
    return np.asarray(pcd.points).T

def extract_fpfh(pcd, voxel_size):
    radius_normal = voxel_size * 2
    pcd.estimate_normals(
      o3d.geometry.KDTreeSearchParamHybrid(radius=radius_normal, max_nn=30))

    radius_feature = voxel_size * 5
    fpfh = o3d.pipelines.registration.compute_fpfh_feature(
      pcd, o3d.geometry.KDTreeSearchParamHybrid(radius=radius_feature, max_nn=100))
    return np.array(fpfh.data).T

def find_knn_cpu(feat0, feat1, knn=1, return_distance=False):
    feat1tree = cKDTree(feat1)
    dists, nn_inds = feat1tree.query(feat0, k=knn, workers=10)
    if return_distance:
        return nn_inds, dists
    else:
        return nn_inds

def find_correspondences(feats0, feats1, mutual_filter=True):
    nns01 = find_knn_cpu(feats0, feats1, knn=1, return_distance=False)
    corres01_idx0 = np.arange(len(nns01))
    corres01_idx1 = nns01

    if not mutual_filter:
        return corres01_idx0, corres01_idx1

    nns10 = find_knn_cpu(feats1, feats0, knn=1, return_distance=False)
    corres10_idx1 = np.arange(len(nns10))
    corres10_idx0 = nns10

    mutual_filter = (corres10_idx0[corres01_idx1] == corres01_idx0)
    corres_idx0 = corres01_idx0[mutual_filter]
    corres_idx1 = corres01_idx1[mutual_filter]

    return corres_idx0, corres_idx1

def get_teaser_solver(noise_bound):
    solver_params = teaserpp_python.RobustRegistrationSolver.Params()
    solver_params.cbar2 = 1.0
    solver_params.noise_bound = noise_bound
    solver_params.estimate_scaling = False
    solver_params.inlier_selection_mode = \
        teaserpp_python.RobustRegistrationSolver.INLIER_SELECTION_MODE.PMC_EXACT
    solver_params.rotation_tim_graph = \
        teaserpp_python.RobustRegistrationSolver.INLIER_GRAPH_FORMULATION.CHAIN
    solver_params.rotation_estimation_algorithm = \
        teaserpp_python.RobustRegistrationSolver.ROTATION_ESTIMATION_ALGORITHM.GNC_TLS
    solver_params.rotation_gnc_factor = 1.4
    solver_params.rotation_max_iterations = 10000
    solver_params.rotation_cost_threshold = 1e-16
    solver = teaserpp_python.RobustRegistrationSolver(solver_params)
    return solver

def Rt2T(R,t):
    T = np.identity(4)
    T[:3,:3] = R
    T[:3,3] = t
    return T 

def save_results(animal_id, data_path, mesh, pcd_downsampled, sa, v):
    # Save the mesh and PCD
    mesh_filename = os.path.join(data_path, f"{animal_id}_mesh.ply")
    pcd_filename = os.path.join(data_path, f"{animal_id}_pcd_downsampled.ply")
    
    #print(mesh_filename)
    #print(pcd_filename)
    o3d.io.write_triangle_mesh(mesh_filename, mesh)
    
    o3d.io.write_point_cloud(pcd_filename, pcd_downsampled)

    CSV_PATH = '/home/vigir3d/Datasets/cattle_scans/cow_measurements.csv'
    # Check if CSV file exists to decide whether to write headers
    write_header = not os.path.exists(CSV_PATH)
  # Save SA & V to the CSV file in append mode
    with open(CSV_PATH, 'a', newline='') as csvfile:
        fieldnames = ['Animal ID', 'SA', 'V']
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
        
        if write_header:
            writer.writeheader()

        writer.writerow({'Animal ID': animal_id, 'SA': sa, 'V': v})

        
@jit(nopython=True, parallel=True)
def numba_eliminate_flying_pixels(depth_image, ws, threshold):
    height, width = depth_image.shape
    result = np.zeros_like(depth_image, dtype=np.float64)
    
    for cy in prange(height):
        for cx in prange(width):
            x_start, x_end = max(0, cx - ws), min(width, cx + ws + 1)
            y_start, y_end = max(0, cy - ws), min(height, cy + ws + 1)
            window = depth_image[y_start:y_end, x_start:x_end]
            result[cy, cx] = np.sum(np.abs(window - depth_image[cy, cx]))
    
    return result


def colored_ICP_teaser(source, target, initial_tform):
    
    voxel_radius = [0.04, 0.02, 0.01]
    max_iter = [50, 30, 14]
    current_transformation = initial_tform
    #print("3. Colored point cloud registration")
    for scale in range(3):
        iters = max_iter[scale]
        radius = voxel_radius[scale]
        #print("iteration: ", iters, radius, scale)

        #print("3-1. Downsample with a voxel size %.2f" % radius)
        source_down = copy.deepcopy(source).voxel_down_sample(radius)
        target_down = copy.deepcopy(target).voxel_down_sample(radius)

        #print("3-2. Estimate normal.")
        source_down.estimate_normals(
            o3d.geometry.KDTreeSearchParamHybrid(radius=radius * 2, max_nn=30))
        target_down.estimate_normals(
            o3d.geometry.KDTreeSearchParamHybrid(radius=radius * 2, max_nn=30))

        #print("3-3. Applying colored point cloud registration")
        result_icp = o3d.pipelines.registration.registration_colored_icp(
            source_down, target_down, radius, current_transformation,
            o3d.pipelines.registration.TransformationEstimationForColoredICP(),
            o3d.pipelines.registration.ICPConvergenceCriteria(relative_fitness=1e-6,
                                                              relative_rmse=1e-6,
                                                              max_iteration=iters))
        current_transformation = result_icp.transformation
    
   
        #draw_registration_result(source, target, current_transformation)
    return current_transformation


def colored_ICP(source, target):
    
    voxel_radius = [0.04, 0.02, 0.01]
    max_iter = [50, 30, 14]
    current_transformation = np.identity(4)
    #print("3. Colored point cloud registration")
    for scale in range(3):
        iters = max_iter[scale]
        radius = voxel_radius[scale]
        #print("iteration: ", iters, radius, scale)

        #print("3-1. Downsample with a voxel size %.2f" % radius)
        source_down = copy.deepcopy(source).voxel_down_sample(radius)
        target_down = copy.deepcopy(target).voxel_down_sample(radius)

        #print("3-2. Estimate normal.")
        source_down.estimate_normals(
            o3d.geometry.KDTreeSearchParamHybrid(radius=radius * 2, max_nn=30))
        target_down.estimate_normals(
            o3d.geometry.KDTreeSearchParamHybrid(radius=radius * 2, max_nn=30))

        #print("3-3. Applying colored point cloud registration")
        result_icp = o3d.pipelines.registration.registration_colored_icp(
            source_down, target_down, radius, current_transformation,
            o3d.pipelines.registration.TransformationEstimationForColoredICP(),
            o3d.pipelines.registration.ICPConvergenceCriteria(relative_fitness=1e-6,
                                                              relative_rmse=1e-6,
                                                              max_iteration=iters))
        current_transformation = result_icp.transformation
    
   
        #draw_registration_result(source, target, current_transformation)
    return current_transformation

def backproject_o3d(rgbd_frame, intrinsics):
    
    rgbdc = o3d.geometry.RGBDImage.create_from_color_and_depth(
        rgbd_frame.color, rgbd_frame.depth, depth_trunc=4.0, convert_rgb_to_intensity=False)
    pcd = o3d.geometry.PointCloud.create_from_rgbd_image(rgbdc, intrinsics)
    n_radius = 0.01*2.0
    pcd.estimate_normals(
    search_param=o3d.geometry.KDTreeSearchParamHybrid(radius=n_radius, max_nn=30))
    
    return pcd



def load_maskrcnn_model(model_path):
    model = torchvision.models.detection.maskrcnn_resnet50_fpn(weights="DEFAULT")
    in_features = model.roi_heads.box_predictor.cls_score.in_features
    model.roi_heads.box_predictor = FastRCNNPredictor(in_features, 2)
    in_features_mask = model.roi_heads.mask_predictor.conv5_mask.in_channels
    hidden_layer = 256
    model.roi_heads.mask_predictor = MaskRCNNPredictor(in_features_mask, hidden_layer, 2)
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model.to(device)
    model.load_state_dict(torch.load(model_path))
    model.eval()

    return model

def get_model_mask(model_generic, image):
    proba_threshold = 0.5
    ig = transform(image)
    with torch.no_grad():
        prediction = model_generic([ig.to(device)])
        
    if(prediction[0]['masks'].nelement() == 0):
        XX = torch.empty((0,0), dtype=torch.int64)
        return XX
    predicted_mask = prediction[0]
    predicted_mask = predicted_mask['masks'][0] > proba_threshold
    
    predicted_mask = predicted_mask.squeeze(1)
    mask = predicted_mask.cpu().detach()
    return mask


def segment_images_modified(last_frame):
    depth_image_array = np.asarray(last_frame.depth)
    #print("Pre:",np.max(depth_image_array), " -- ", np.min(depth_image_array))
    depth_PIL = Image.fromarray(np.asarray(last_frame.depth)).convert("RGB")
    rgb_image_array = np.asarray(last_frame.color)
    rgb_PIL = Image.fromarray(rgb_image_array)

    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    rgb_mask = get_model_mask(model_rgb, rgb_PIL)
    depth_mask = get_model_mask(model_depth, depth_PIL)

    if depth_mask.nelement() == 0:
        mask_combined = rgb_mask
    else:
        mask_combined = depth_mask | rgb_mask  # 1 vote arbitration (OR the masks)

    # Convert tensor to numpy array and ensure the right datatype
    mask_combined = mask_combined.numpy().astype(rgb_image_array.dtype)
    mask_image = mask_combined.swapaxes(0, 2).swapaxes(0, 1)
    mask_image = (mask_image > 0).astype(rgb_image_array.dtype)   

    fg_image_rgb = rgb_image_array * mask_image

    # For the depth image:
    squeezed_mask = np.squeeze(mask_image)
    fg_image_depth = (depth_image_array * squeezed_mask)*1000 # upscale because re-inserting in "last_frame" rescales
    
    #print("Post:" ,np.max(fg_image_depth), " -- ", np.min(fg_image_depth))
    last_frame.color = o3d.geometry.Image(fg_image_rgb)
    last_frame.depth = o3d.geometry.Image(fg_image_depth)

    return last_frame




def draw_registration_result(source, target, transformation):
    source_temp = copy.deepcopy(source)
    target_temp = copy.deepcopy(target)
    source_temp.paint_uniform_color([1, 0.706, 0])
    target_temp.paint_uniform_color([0, 0.651, 0.929])
    source_temp.transform(transformation)
    o3d.visualization.draw_geometries([source_temp, target_temp])

def cluster_point_cloud_new(outlier_cloud):
    cloud_colors = copy.deepcopy(np.asarray(outlier_cloud.colors).T)
    
    with o3d.utility.VerbosityContextManager(o3d.utility.VerbosityLevel.Error) as cm:
        labels = np.array(outlier_cloud.cluster_dbscan(eps=0.05, min_points=10, print_progress=False))

    # Identify the largest cluster
    values, counts = np.unique(labels, return_counts=True)
    ind = np.argmax(counts)
    largest_cluster_label = values[ind]
    #print(f"Largest cluster label: {largest_cluster_label}")

    # Filter points, normals, and colors for the largest cluster
    cloud_xyz = pcd2xyz(outlier_cloud)
    cloud_normals = pcd2normals(outlier_cloud)

    cloud_filtered = cloud_xyz[:, labels == largest_cluster_label]
    normals_filtered = cloud_normals[:, labels == largest_cluster_label]
    colors_filtered = cloud_colors[:, labels == largest_cluster_label]

    # Create a point cloud for the largest cluster
    pcd_filtered_largest_cluster = o3d.geometry.PointCloud()
    pcd_filtered_largest_cluster.points = o3d.utility.Vector3dVector(cloud_filtered.T)
    pcd_filtered_largest_cluster.normals = o3d.utility.Vector3dVector(normals_filtered.T)
    pcd_filtered_largest_cluster.colors = o3d.utility.Vector3dVector(colors_filtered.T)

    #o3d.visualization.draw_geometries([pcd_filtered_largest_cluster])
    return pcd_filtered_largest_cluster

def load_calibration(tform_path, num_transforms=5):
    transforms = [np.eye(4)]  # Initialize with identity matrix
    
    # Load transformations from file
    for i in range(1, num_transforms+1):
        filename = tform_path + f"H_0_{i}.txt"
        
        if not os.path.exists(filename):
            raise FileNotFoundError(f"The file {filename} does not exist!")
        
        transforms.append(np.loadtxt(filename))
    
    return transforms

def upsample_using_reference_normals_new(sparse_pcd, dense_pcd, search_radius=0.02, angle_threshold=30):
    # Ensure the point clouds have normals
    if not sparse_pcd.has_normals():
        sparse_pcd.estimate_normals()
    if not dense_pcd.has_normals():
        dense_pcd.estimate_normals()

    dense_points = np.asarray(dense_pcd.points)
    dense_tree = cKDTree(dense_points)

    sparse_points = np.asarray(sparse_pcd.points)
    sparse_normals = np.asarray(sparse_pcd.normals)
    sparse_colors = np.asarray(sparse_pcd.colors)

    
    # This retrieves the indices of all neighbors within the search_radius
    neighbor_indices = dense_tree.query_ball_point(sparse_points, search_radius, workers=-1)
    
    valid_indices = []
    for i, idx_row in enumerate(neighbor_indices):
        neighbors = dense_points[idx_row]
        neighbor_normals = np.asarray(dense_pcd.normals)[idx_row]
        neighbor_colors = np.asarray(dense_pcd.colors)[idx_row]

        # Calculate angles between sparse point's normal and all its neighbors' normals
        angles = np.degrees(np.arccos(np.clip(np.dot(sparse_normals[i], neighbor_normals.T), -1.0, 1.0)))

        # Filtering neighbors based on angle threshold
        valid_neighbor_indices = np.array(idx_row)[angles < angle_threshold]
        valid_indices.extend(valid_neighbor_indices)

    unique_valid_indices = np.unique(valid_indices)
    final_valid_neighbors = dense_points[unique_valid_indices]
    final_valid_normals = np.asarray(dense_pcd.normals)[unique_valid_indices]
    final_valid_colors = np.asarray(dense_pcd.colors)[unique_valid_indices]
    
    upsampled_points = np.vstack([sparse_points, final_valid_neighbors])
    upsampled_normals = np.vstack([sparse_normals, final_valid_normals])
    upsampled_colors = np.vstack([sparse_colors, final_valid_colors])
    
    upsampled_pcd = o3d.geometry.PointCloud()
    upsampled_pcd.points = o3d.utility.Vector3dVector(upsampled_points)
    upsampled_pcd.normals = o3d.utility.Vector3dVector(upsampled_normals)
    upsampled_pcd.colors = o3d.utility.Vector3dVector(upsampled_colors)
    
    return upsampled_pcd

def process_file_list_comp(file_id, dpath,tform):
    global globT
    ws = 2
    # Format filenames
    dpath = dpath.rstrip('/')

    # Split by the directory separator and get the last part
    suffix = os.path.basename(dpath)
    
    file_suffix = suffix + "_nano_" + str(file_id)
    # Construct full file paths using os.path.join for better cross-platform compatibility
    depth_file = os.path.join(dpath, file_suffix + "_depth.png")
    color_file = os.path.join(dpath, file_suffix + ".jpg")
    intrinsics_file = os.path.join(dpath, file_suffix + "_intrinsics.txt")
    # Read the files
    depth = o3d.io.read_image(depth_file)
    color = o3d.io.read_image(color_file)
    #depth = o3d.io.read_image(dpath + 'Animal_box3_u_nano_11_depth.png')
    #color = o3d.io.read_image(dpath + 'Animal_box3_u_nano_11.jpg')
    K = np.loadtxt(intrinsics_file)
      

    camera_intrinsics = o3d.camera.PinholeCameraIntrinsic()
    camera_intrinsics.set_intrinsics(int(K[0]), int(K[1]), K[2], K[3], K[4], K[5])

    rgbdc = o3d.geometry.RGBDImage.create_from_color_and_depth(
        color, depth, depth_trunc=4.0, convert_rgb_to_intensity=False
    )

    volume = o3d.pipelines.integration.ScalableTSDFVolume(
        voxel_length=4.0 / 512.0, sdf_trunc=0.04, color_type=o3d.pipelines.integration.TSDFVolumeColorType.RGB8
    )
    
    volume.integrate(rgbdc, camera_intrinsics, np.eye(4))
    pcd_tsdf = volume.extract_point_cloud()
    pcd_tsdf.transform(tform)
    depth_np = np.asarray(rgbdc.depth)
    
    if ( depth_np.max() > 20 ) : # Depth is in millimeters
        flying_pixel_filter_threshold = 100 # 100
    else : # meters
        flying_pixel_filter_threshold = 0.1 # 0.1
        #print(flying_pixel_filter_threshold, " -- ", depth_np.max())

    result_mask = numba_eliminate_flying_pixels(depth_np.copy(), ws, flying_pixel_filter_threshold)
    depth_np[result_mask > flying_pixel_filter_threshold] = 0
    # Re-insert filtered depth into the rgbd image
    rgbdc.depth = o3d.geometry.Image(depth_np)
    # Apply maskrcnn to filtered depth image
    t1 = time.time()
    masked_rgbd = segment_images_modified(rgbdc)
    t2 = time.time()
    T = t2-t1
    globT+=T
    #print("Duration for maskrcnn 1 image ",file_id, ": ", T , "s")
    # necessary lol
    rgbdc_new = o3d.geometry.RGBDImage.create_from_color_and_depth(
                    masked_rgbd.color, masked_rgbd.depth, depth_trunc=4.0, convert_rgb_to_intensity=False)
    d = np.asarray(rgbdc_new.depth)

    v = o3d.pipelines.integration.ScalableTSDFVolume(
        voxel_length=4.0 / 512.0, sdf_trunc=0.04, color_type=o3d.pipelines.integration.TSDFVolumeColorType.RGB8
    )

    v.integrate(rgbdc_new, camera_intrinsics, np.eye(4))
    pcd_tmp = v.extract_point_cloud()
    pcd_tmp.transform(tform)
    #pcd_tmp = o3d.geometry.PointCloud.create_from_rgbd_image(rgbdc_new,
     #                                                   camera_intrinsics)

    return pcd_tmp, pcd_tsdf

def perform_pairwise_alignment(pcds_tsdf,pcds_cropped):
    """Compute and apply transformations."""
    t01 = colored_ICP(pcds_tsdf[0], pcds_tsdf[1])
    t52 = colored_ICP(pcds_tsdf[5], pcds_tsdf[2])
    t43 = colored_ICP(pcds_tsdf[4], pcds_tsdf[3])
    t12 = colored_ICP(pcds_tsdf[1], pcds_tsdf[2])
    t32 = colored_ICP(pcds_tsdf[3], pcds_tsdf[2])

    H0 = t12 @ t01
    H1 = t12
    H3 = t32
    H4 = t32 @ t43
    H5 = t52

    # Transform the point clouds
    p0 = copy.deepcopy(pcds_cropped[0]).transform(H0)
    p1 = copy.deepcopy(pcds_cropped[1]).transform(H1)
    p3 = copy.deepcopy(pcds_cropped[3]).transform(H3)
    p4 = copy.deepcopy(pcds_cropped[4]).transform(H4)
    p5 = copy.deepcopy(pcds_cropped[5]).transform(H5)
    
    d0 = copy.deepcopy(pcds_tsdf[0]).transform(H0)
    d1 = copy.deepcopy(pcds_tsdf[1]).transform(H1)
    d3 = copy.deepcopy(pcds_tsdf[3]).transform(H3)
    d4 = copy.deepcopy(pcds_tsdf[4]).transform(H4)
    d5 = copy.deepcopy(pcds_tsdf[5]).transform(H5)
    
    pcd_combined = o3d.geometry.PointCloud()
    pcd_combined = p0+p1+pcds_cropped[2]+p3+p4+p5
    
    ptsdf_combined = o3d.geometry.PointCloud()
    ptsdf_combined = d0+d1+pcds_tsdf[2]+d3+d4+d5

    return pcd_combined, ptsdf_combined
def pcd2normals(pcd):
    return np.asarray(pcd.normals).T


def call_cpp_program(directory_path):
    # Adjust this to the path of your compiled C++ executable if it's not in the system's PATH.
    cpp_executable = "/home/vigir3d/Software/programs/k4a-read-mkvs/build/k4a_read_mkv"
    command = cpp_executable + " " + directory_path + "*.mkv"
    #print(command)
    # Call the C++ program.
    result = subprocess.run(command, shell=True, check=True)

    # Check if the C++ program executed without errors.
    if result.returncode != 0:
        print(f"Error running {cpp_executable}")
        return False

    return True

def combine_pcds(pcds):
    pcd_combined = o3d.geometry.PointCloud()
    
    pcd_combined = pcds[0]+pcds[1]+pcds[2]+pcds[3]+pcds[4]+pcds[5]
    
    return pcd_combined
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.

# %%
def combine_pcds(pcds):
    pcd_combined = o3d.geometry.PointCloud()
    
    pcd_combined = pcds[0]+pcds[1]+pcds[2]+pcds[3]+pcds[4]+pcds[5]
    
    return pcd_combined

# %%
# for DISTANCE SA MEASURES
def process_file_list_generic(file_id, dpath,tform=np.eye(4), mode = "NFOV"):
    ws = 2
    flying_pixel_filter_threshold = 1000
    # Format filenames
    dpath = dpath.rstrip('/')

    # Split by the directory separator and get the last part
    suffix = "obj_"    
    file_suffix = suffix + str(file_id) +"ft_" + mode
    print(file_suffix)
    # Construct full file paths using os.path.join for better cross-platform compatibility
    depth_file = os.path.join(dpath, file_suffix + "_depth.png")
    color_file = os.path.join(dpath, file_suffix + ".jpg")
    intrinsics_file = os.path.join(dpath, file_suffix + "_intrinsics.txt")
    # Read the files
    depth = o3d.io.read_image(depth_file)
    color = o3d.io.read_image(color_file)
    #depth = o3d.io.read_image(dpath + 'Animal_box3_u_nano_11_depth.png')
    #color = o3d.io.read_image(dpath + 'Animal_box3_u_nano_11.jpg')
    K = np.loadtxt(intrinsics_file)
      
    
    camera_intrinsics = o3d.camera.PinholeCameraIntrinsic()
    camera_intrinsics.set_intrinsics(int(K[0]), int(K[1]), K[2], K[3], K[4], K[5])

    rgbdc = o3d.geometry.RGBDImage.create_from_color_and_depth(
        color, depth, depth_trunc=4.0, convert_rgb_to_intensity=False
    )

    volume = o3d.pipelines.integration.ScalableTSDFVolume(
        voxel_length=4.0 / 512.0, sdf_trunc=0.04, color_type=o3d.pipelines.integration.TSDFVolumeColorType.RGB8
    )

    volume.integrate(rgbdc, camera_intrinsics, np.eye(4))
    pcd_tsdf = volume.extract_point_cloud()
    pcd_tsdf.transform(tform)
    output_fname = os.path.join(dpath,file_suffix+".ply")
    o3d.io.write_point_cloud(output_fname, pcd_tsdf)
    print(f"Writing point cloud: {output_fname}")
    return pcd_tsdf

# %%
# for metab
def process_file_list_comp(file_id, dpath,tform=np.eye(4)):
    ws = 2
    flying_pixel_filter_threshold = 1000
    # Format filenames
    dpath = dpath.rstrip('/')

    # Split by the directory separator and get the last part
    suffix = os.path.basename(dpath)
    
    file_suffix = suffix + "_nano_" + str(file_id)
    # Construct full file paths using os.path.join for better cross-platform compatibility
    depth_file = os.path.join(dpath, file_suffix + "_depth.png")
    color_file = os.path.join(dpath, file_suffix + ".jpg")
    intrinsics_file = os.path.join(dpath, file_suffix + "_intrinsics.txt")
    # Read the files
    depth = o3d.io.read_image(depth_file)
    color = o3d.io.read_image(color_file)
    #depth = o3d.io.read_image(dpath + 'Animal_box3_u_nano_11_depth.png')
    #color = o3d.io.read_image(dpath + 'Animal_box3_u_nano_11.jpg')
    K = np.loadtxt(intrinsics_file)
      
    
    camera_intrinsics = o3d.camera.PinholeCameraIntrinsic()
    camera_intrinsics.set_intrinsics(int(K[0]), int(K[1]), K[2], K[3], K[4], K[5])

    rgbdc = o3d.geometry.RGBDImage.create_from_color_and_depth(
        color, depth, depth_trunc=4.0, convert_rgb_to_intensity=False
    )

    volume = o3d.pipelines.integration.ScalableTSDFVolume(
        voxel_length=4.0 / 512.0, sdf_trunc=0.04, color_type=o3d.pipelines.integration.TSDFVolumeColorType.RGB8
    )

    volume.integrate(rgbdc, camera_intrinsics, np.eye(4))
    pcd_tsdf = volume.extract_point_cloud()
    pcd_tsdf.transform(tform)
    
    return pcd_tsdf

# BEEF FARM /METAB BARN 
def perform_pairwise_alignment(pcds_tsdf):
    """Compute and apply transformations."""
    t01 = colored_ICP(pcds_tsdf[0], pcds_tsdf[1])
    t52 = colored_ICP(pcds_tsdf[5], pcds_tsdf[2])
    t43 = colored_ICP(pcds_tsdf[4], pcds_tsdf[3])
    t12 = colored_ICP(pcds_tsdf[1], pcds_tsdf[2])
    t32 = colored_ICP(pcds_tsdf[3], pcds_tsdf[2])

    H0 = t12 @ t01
    H1 = t12
    H3 = t32
    H4 = t32 @ t43
    H5 = t52

    # Transform the point clouds
    p0 = copy.deepcopy(pcds_tsdf[0]).transform(H0)
    p1 = copy.deepcopy(pcds_tsdf[1]).transform(H1)
    p3 = copy.deepcopy(pcds_tsdf[3]).transform(H3)
    p4 = copy.deepcopy(pcds_tsdf[4]).transform(H4)
    p5 = copy.deepcopy(pcds_tsdf[5]).transform(H5)
    o3d.visualization.draw_geometries([p0,p1,p3,p4,p5,pcds_tsdf[2]])
    pcd_all = o3d.geometry.PointCloud()
    pcd_all = p0+p1+p3+p4+p5+pcds_tsdf[2]
    
    return pcd_all

# %%
combined_pcds = o3d.geometry.PointCloud()
combined_pcds = [pcd+=pcd for pcd in results]

# %%
# construct transform matrices
H0 = t12 @ t01
H1 = t12
H3 = t32
H4 = t32 @ inv(t34)
H5 = t52
# apply transformations
p0 = copy.deepcopy(results[0]).transform(H0)
p1 = copy.deepcopy(results[1]).transform(H1)
p3 = copy.deepcopy(results[3]).transform(H3)
p4 = copy.deepcopy(results[4]).transform(H4)
p5 = copy.deepcopy(results[5]).transform(H5)
o3d.visualization.draw_geometries([p0,p1,p3,p4,p5,results[2]])
pcd_all = o3d.geometry.PointCloud()
pcd_all = p0+p1+p3+p4+p5+results[2]

# %%
# construct transform matrices
H0 = t12 @ t01
H1 = t12
H3 = t42 @ t34
H4 = t42
H5 = t52

# apply transformations
p0 = copy.deepcopy(results[0]).transform(H0)
p1 = copy.deepcopy(results[1]).transform(H1)
p3 = copy.deepcopy(results[3]).transform(H3)
p4 = copy.deepcopy(results[4]).transform(H4)
p5 = copy.deepcopy(results[5]).transform(H5)
o3d.visualization.draw_geometries([p0,p1,p3,p4,p5,results[2]])
pcd_all = o3d.geometry.PointCloud()
pcd_all = p0+p1+p3+p4+p5+results[2]

# %%
o3d.visualization.draw_geometries([pcd_all])
o3d.io.write_point_cloud(os.path.join(result_path,animal_name+"_teaser.ply"), pcd_all)

# %%
pcds = [r01,r34,r52,r32,r02]
for i in range(len(pcds)):
    o3d.visualization.draw_geometries([pcds[i]])

# %%
o3d.visualization.draw_geometries([r52])

# %%
import glob
import os
import re


# Pattern to match the files
pattern = os.path.join(result_path, 'Animal_k*.ply')

# List all matching files
matching_files = glob.glob(pattern)

# Use regular expression to match the desired pattern
filename_pattern = re.compile(r'^Animal_k(\d+)_teaser\.ply$')

# Extract the matched filenames
filtered_files = [os.path.basename(f) for f in matching_files if filename_pattern.match(os.path.basename(f))]

# Generate the final list of "Animal_k12", "Animal_k3", etc.
final_list = [re.match(r'^(.+)_teaser\.ply$', f).group(1) for f in filtered_files]

print(final_list)
# Out:
# ['Animal_k52', 'Animal_k118', 'Animal_k31', 'Animal_k209', 'Animal_k94', 'Animal_k102', 'Animal_k3', 'Animal_k111', 'Animal_k124', 'Animal_k194', 'Animal_k176', 'Animal_k66', 'Animal_k65', 'Animal_k201', 'Animal_k57', 'Animal_k175', 'Animal_k12', 'Animal_k37', 'Animal_k131', 'Animal_k17', 'Animal_k189', 'Animal_k63', 'Animal_k34', 'Animal_k99', 'Animal_k106', 'Animal_k2', 'Animal_k83', 'Animal_k98', 'Animal_k82', 'Animal_k27', 'Animal_k178', 'Animal_k180', 'Animal_k119', 'Animal_k110', 'Animal_k76', 'Animal_k88', 'Animal_k123', 'Animal_k56', 'Animal_k134']

# %%
def register_two_views_teaser(A_pcd_raw,B_pcd_raw,VOXEL_SIZE):
    
    VISUALIZE = True
    A_pcd = A_pcd_raw.voxel_down_sample(voxel_size=VOXEL_SIZE)
    B_pcd = B_pcd_raw.voxel_down_sample(voxel_size=VOXEL_SIZE)
    #if VISUALIZE:
     #   o3d.visualization.draw_geometries([A_pcd,B_pcd]) # plot downsampled A and B 

    A_xyz = pcd2xyz(A_pcd) # np array of size 3 by N
    B_xyz = pcd2xyz(B_pcd) # np array of size 3 by M

    print("Extracting FPFH features")
    # extract FPFH features
    A_feats = extract_fpfh(A_pcd,VOXEL_SIZE)
    B_feats = extract_fpfh(B_pcd,VOXEL_SIZE)
    print(A_feats.shape)
    print("Computing FPFH correspondences")
    # establish correspondences by nearest neighbour search in feature space
    corrs_A, corrs_B = find_correspondences(
        A_feats, B_feats, mutual_filter=True)
    A_corr = A_xyz[:,corrs_A] # np array of size 3 by num_corrs
    B_corr = B_xyz[:,corrs_B] # np array of size 3 by num_corrs

    num_corrs = A_corr.shape[1]
    print(f'FPFH generates {num_corrs} putative correspondences.')

    # visualize the point clouds together with feature correspondenc
    # robust global registration using TEASER++
    NOISE_BOUND = VOXEL_SIZE
    teaser_solver = get_teaser_solver(NOISE_BOUND)
    teaser_solver.solve(A_corr,B_corr)
    solution = teaser_solver.getSolution()
    R_teaser = solution.rotation
    t_teaser = solution.translation
    T_teaser = Rt2T(R_teaser,t_teaser)

    # Visualize the registration results
    A_pcd_T_teaser = copy.deepcopy(A_pcd).transform(T_teaser)
    #o3d.visualization.draw_geometries([A_pcd_T_teaser,B_pcd])

    # local refinement using ICP
    icp_sol = o3d.pipelines.registration.registration_icp(
          A_pcd, B_pcd, NOISE_BOUND, T_teaser,
          o3d.pipelines.registration.TransformationEstimationPointToPoint(),
          o3d.pipelines.registration.ICPConvergenceCriteria(max_iteration=100))
    T_icp = icp_sol.transformation
    
#     T_cicp = colored_ICP_teaser(A_pcd, B_pcd, T_teaser)
    
#     # visualize the registration after COLORED ICP refinement
#     A_pcd_T_cicp = copy.deepcopy(A_pcd).transform(T_cicp)
#     if VISUALIZE:
#         Acopy = copy.deepcopy(A_pcd_T_cicp).paint_uniform_color([0.0,0.0,1])
#         Bcopy = copy.deepcopy(B_pcd).paint_uniform_color([1.0,0.0,0.0])
#         o3d.visualization.draw_geometries([Acopy,Bcopy])
    

    # visualize the registration after ICP refinement
    A_pcd_T_icp = copy.deepcopy(A_pcd).transform(T_icp)
    if VISUALIZE:
        Acopy = copy.deepcopy(A_pcd_T_icp).paint_uniform_color([0.0,0.0,1])
        Bcopy = copy.deepcopy(B_pcd).paint_uniform_color([1.0,0.0,0.0])
        o3d.visualization.draw_geometries([Acopy,Bcopy])
    tformed_A = copy.deepcopy(A_pcd_raw).transform(T_icp)
    res = o3d.geometry.PointCloud()
    res = tformed_A + B_pcd_raw
    
    return res,T_icp

# %%
print(len(final_list))
# Out:
# 39

# %%
# 2a, 13d, 15a,16a
# 12d, 14d, 3, 1d,4a,5c,8c, 9e

for current_animal in final_list:
    base_path = '/home/vigir3d/Datasets/cattle_scans/thompson4/'
    calib_path = os.path.join(base_path,'Animal_calib_1/')
    dpath = os.path.join(base_path,current_animal+"/")
    result_path = os.path.join(base_path,'registered_cattle/')
    animal_name = os.path.basename(dpath.rstrip('/'))
    print(animal_name)
    success = call_cpp_program(dpath)
    if not success:
        print("Failed to process MKV files with the C++ program.")
    else:
        print("success!!")
        #tforms = load_calibration(calib_path)
        tforms = [np.eye(4) for _ in range(6)]
        file_ids = [11,12,15,19,18,20]  # exclude head cameras

        # Generate a list of volumes using list comprehension
        start = time.time()

        results = [process_file_list_comp(file_id, dpath, tform) for file_id, tform in zip(file_ids,tforms)]
#         r01,t01 = register_two_views_teaser(results[0],results[1], 0.05)
#         r34,t34 = register_two_views_teaser(results[3],results[4], 0.05)
#         r52,t52 = register_two_views_teaser(results[5],results[2], 0.035) #0.035
#         r32,t32 = register_two_views_teaser(r34,r52, 0.032) # |
#         r02, t02 = register_two_views_teaser(r01,r52, 0.05)
#         rall,tall = register_two_views_teaser(r02,r32, 0.05)
        a0 = copy.deepcopy(results[0]).transform(t02@t01)
        a1 = copy.deepcopy(results[1]).transform(t02)
        a3 = copy.deepcopy(results[3]).transform(t32@t34)
        a4 = copy.deepcopy(results[4]).transform(t32)
        a5 = copy.deepcopy(results[5]).transform(t52)

        #o3d.visualization.draw_geometries([a0,a1, a3, a4,a5,results[2]])
        pcd_all = o3d.geometry.PointCloud()
        pcd_all = a0+a1+a3+a4+a5+results[2]

        o3d.visualization.draw_geometries([pcd_all])
        animal_fname = os.path.basename(current_animal.rstrip('/'))
        #print(animal_fname)
        file_name = animal_fname+"_teaser.ply"
        print(file_name)
        o3d.io.write_point_cloud(os.path.join(result_path,file_name), pcd_all)
        
    # perform fine registration
    #reg_animal = perform_pairwise_alignment(results)
# Out:
# Animal_k52
# success!!
# Animal_k52_teaser.ply
# Animal_k118
# success!!
# Animal_k118_teaser.ply
# Animal_k31
# success!!
# Animal_k31_teaser.ply
# Animal_k209
# success!!
# Animal_k209_teaser.ply
# Animal_k94
# success!!
# Animal_k94_teaser.ply
# Animal_k102
# success!!
# Animal_k102_teaser.ply
# Animal_k3
# success!!
# Animal_k3_teaser.ply
# Animal_k111
# success!!
# Animal_k111_teaser.ply
# Animal_k124
# success!!
# Animal_k124_teaser.ply
# Animal_k194
# success!!
# Animal_k194_teaser.ply
# Animal_k176
# success!!
# Animal_k176_teaser.ply
# Animal_k66
# success!!
# Animal_k66_teaser.ply
# Animal_k65
# success!!
# Animal_k65_teaser.ply
# Animal_k201
# success!!
# Animal_k201_teaser.ply
# Animal_k57
# success!!
# Animal_k57_teaser.ply
# Animal_k175
# success!!
# Animal_k175_teaser.ply
# Animal_k12
# success!!
# Animal_k12_teaser.ply
# Animal_k37
# success!!
# Animal_k37_teaser.ply
# Animal_k131
# success!!
# Animal_k131_teaser.ply
# Animal_k17
# success!!
# Animal_k17_teaser.ply
# Animal_k189
# success!!
# Animal_k189_teaser.ply
# Animal_k63
# success!!
# Animal_k63_teaser.ply
# Animal_k34
# success!!
# Animal_k34_teaser.ply
# Animal_k99
# success!!
# Animal_k99_teaser.ply
# Animal_k106
# success!!
# Animal_k106_teaser.ply
# Animal_k2
# success!!
# Animal_k2_teaser.ply
# Animal_k83
# success!!
# Animal_k83_teaser.ply
# Animal_k98
# success!!
# Animal_k98_teaser.ply
# Animal_k82
# success!!
# Animal_k82_teaser.ply
# Animal_k27
# success!!
# Animal_k27_teaser.ply
# Animal_k178
# success!!
# Animal_k178_teaser.ply
# Animal_k180
# success!!
# Animal_k180_teaser.ply
# Animal_k119
# success!!
# Animal_k119_teaser.ply
# Animal_k110
# success!!
# Animal_k110_teaser.ply
# Animal_k76
# success!!
# Animal_k76_teaser.ply
# Animal_k88
# success!!
# Animal_k88_teaser.ply
# Animal_k123
# success!!
# Animal_k123_teaser.ply
# Animal_k56
# success!!
# Animal_k56_teaser.ply
# Animal_k134
# success!!
# Animal_k134_teaser.ply

# %%
a0 = copy.deepcopy(results[0]).transform(t02@t01)
a1 = copy.deepcopy(results[1]).transform(t02)
a3 = copy.deepcopy(results[3]).transform(t32@t34)
a4 = copy.deepcopy(results[4]).transform(t32)
a5 = copy.deepcopy(results[5]).transform(t52)

#o3d.visualization.draw_geometries([a0,a1, a3, a4,a5,results[2]])
pcd_all = o3d.geometry.PointCloud()
pcd_all = a0+a1+a3+a4+a5+results[2]
o3d.visualization.draw_geometries([pcd_all])

# %%
rall,tall = register_two_views_teaser(r02,r32, 0.05)
# Out:
# Extracting FPFH features
# (11139, 33)
# Computing FPFH correspondences
# FPFH generates 2510 putative correspondences.
# Starting scale solver (only selecting inliers if scale estimation has been disabled).
# Scale estimation complete.
# Max core number: 391
# Num vertices: 2511
# Max Clique of scale estimation inliers:
# Using chain graph for GNC rotation.
# Starting rotation solver.
# GNC rotation estimation noise bound:0.1
# GNC rotation estimation noise bound squared:0.01
# GNC-TLS solver terminated due to cost convergence.
# Cost diff: 0
# Iterations: 17
# Rotation estimation complete.
# Starting translation solver.
# Translation estimation complete.

# %%
# 0.05 for 3 to 4
# 0.05 for 0 to 1
# 0.05 for 5 to 2
# 0.025 for 1,2
# 0.0325 for 4 to 2

#r01,t01 = register_two_views_teaser(results[0],results[1], 0.05)
#r34,t34 = register_two_views_teaser(results[3],results[4], 0.05)
#r52,t52 = register_two_views_teaser(results[5],results[2], 0.035) #0.035
#r32,t32 = register_two_views_teaser(r34,r52, 0.044) # |
#r02, t02 = register_two_views_teaser(r01,r52, 0.035)
rall,tall = register_two_views_teaser(r02,r32, 0.05)
# Out:
# Extracting FPFH features
# (11875, 33)
# Computing FPFH correspondences
# FPFH generates 2900 putative correspondences.
# Starting scale solver (only selecting inliers if scale estimation has been disabled).
# Scale estimation complete.
# Max core number: 409
# Num vertices: 2901
# Max Clique of scale estimation inliers:
# Using chain graph for GNC rotation.
# Starting rotation solver.
# GNC rotation estimation noise bound:0.1
# GNC rotation estimation noise bound squared:0.01
# GNC-TLS solver terminated due to cost convergence.
# Cost diff: 0
# Iterations: 23
# Rotation estimation complete.
# Starting translation solver.
# Translation estimation complete.

# %%
44,49, 52

# %%
vs
# Out:
# 0.07000000000000002

# %%
(0.45,0.48,0.49), 43,46,55,59

# %%
o3d.visualization.draw_geometries([rall])

# %%
print(animal_name)
print(result_path)
# Out:
# Animal_a1_1
# /home/vigir3d/Datasets/cattle_scans/trowbridge_09_09/registered_cattle/

# %%
# depth_model_path = '/home/vigir3d/Datasets/cattle_scans/maskrcnn_data/maskrcnn_depth_best.pth'

# ********************** GLOBAL OBJECTS TO BE USED IN NUMEROUS FUNCTIONS **********************
rgb_model_path = '/home/vigir3d/Datasets/cattle_scans/maskrcnn_data/maskrcnn_oct_2024.pth'
depth_model_path = '/home/vigir3d/Datasets/cattle_scans/maskrcnn_data/maskrcnn_depth_oct_2024.pth'
model_rgb = load_maskrcnn_model(rgb_model_path)
model_depth = load_maskrcnn_model(depth_model_path)
transform = T.ToTensor()
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
def process_file_list_comp(file_id, dpath,tform):
    global globT
    ws = 2
    # Format filenames
    dpath = dpath.rstrip('/')

    # Split by the directory separator and get the last part
    suffix = os.path.basename(dpath)
    
    file_suffix = suffix + "_nano_" + str(file_id)
    # Construct full file paths using os.path.join for better cross-platform compatibility
    depth_file = os.path.join(dpath, file_suffix + "_depth.png")
    color_file = os.path.join(dpath, file_suffix + ".jpg")
    intrinsics_file = os.path.join(dpath, file_suffix + "_intrinsics.txt")
    # Read the files
    depth = o3d.io.read_image(depth_file)
    color = o3d.io.read_image(color_file)
    #depth = o3d.io.read_image(dpath + 'Animal_box3_u_nano_11_depth.png')
    #color = o3d.io.read_image(dpath + 'Animal_box3_u_nano_11.jpg')
    K = np.loadtxt(intrinsics_file)
      

    camera_intrinsics = o3d.camera.PinholeCameraIntrinsic()
    camera_intrinsics.set_intrinsics(int(K[0]), int(K[1]), K[2], K[3], K[4], K[5])

    rgbdc = o3d.geometry.RGBDImage.create_from_color_and_depth(
        color, depth, depth_trunc=4.0, convert_rgb_to_intensity=False
    )

    volume = o3d.pipelines.integration.ScalableTSDFVolume(
        voxel_length=4.0 / 512.0, sdf_trunc=0.04, color_type=o3d.pipelines.integration.TSDFVolumeColorType.RGB8
    )
    
    volume.integrate(rgbdc, camera_intrinsics, np.eye(4))
    pcd_tsdf = volume.extract_point_cloud()
    pcd_tsdf.transform(tform)
    depth_np = np.asarray(rgbdc.depth)
    
    if ( depth_np.max() > 20 ) : # Depth is in millimeters
        flying_pixel_filter_threshold = 1e5 # 100
    else : # meters
        flying_pixel_filter_threshold = 1e5 # 0.1
        #print(flying_pixel_filter_threshold, " -- ", depth_np.max())

    result_mask = numba_eliminate_flying_pixels(depth_np.copy(), ws, flying_pixel_filter_threshold)
    depth_np[result_mask > flying_pixel_filter_threshold] = 0
    # Re-insert filtered depth into the rgbd image
    rgbdc.depth = o3d.geometry.Image(depth_np)
    # Apply maskrcnn to filtered depth image
    t1 = time.time()
    masked_rgbd = segment_images_modified(rgbdc)
    t2 = time.time()
    T = t2-t1
    globT+=T
    #print("Duration for maskrcnn 1 image ",file_id, ": ", T , "s")
    # necessary lol
    rgbdc_new = o3d.geometry.RGBDImage.create_from_color_and_depth(
                    masked_rgbd.color, masked_rgbd.depth, depth_trunc=4.0, convert_rgb_to_intensity=False)
    d = np.asarray(rgbdc_new.depth)

    v = o3d.pipelines.integration.ScalableTSDFVolume(
        voxel_length=4.0 / 512.0, sdf_trunc=0.04, color_type=o3d.pipelines.integration.TSDFVolumeColorType.RGB8
    )

    v.integrate(rgbdc_new, camera_intrinsics, np.eye(4))
    pcd_tmp = v.extract_point_cloud()
    pcd_tmp.transform(tform)
    #pcd_tmp = o3d.geometry.PointCloud.create_from_rgbd_image(rgbdc_new,
     #                                                   camera_intrinsics)

    return pcd_tmp, pcd_tsdf
def segment_images_modified(last_frame):
    depth_image_array = np.asarray(last_frame.depth)
    #print("Pre:",np.max(depth_image_array), " -- ", np.min(depth_image_array))
    depth_PIL = Image.fromarray(np.asarray(last_frame.depth)).convert("RGB")
    rgb_image_array = np.asarray(last_frame.color)
    rgb_PIL = Image.fromarray(rgb_image_array)

    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    rgb_mask = get_model_mask(model_rgb, rgb_PIL)
    depth_mask = get_model_mask(model_depth, depth_PIL)

    if depth_mask.nelement() == 0:
        mask_combined = rgb_mask
    else:
        mask_combined = depth_mask | rgb_mask  # 1 vote arbitration (OR the masks)

    # Convert tensor to numpy array and ensure the right datatype
    mask_combined = mask_combined.numpy().astype(rgb_image_array.dtype)
    mask_image = mask_combined.swapaxes(0, 2).swapaxes(0, 1)
    mask_image = (mask_image > 0).astype(rgb_image_array.dtype)   

    fg_image_rgb = rgb_image_array * mask_image

    # For the depth image:
    squeezed_mask = np.squeeze(mask_image)
    fg_image_depth = (depth_image_array * squeezed_mask)*1000 # upscale because re-inserting in "last_frame" rescales
    
    #print("Post:" ,np.max(fg_image_depth), " -- ", np.min(fg_image_depth))
    last_frame.color = o3d.geometry.Image(fg_image_rgb)
    last_frame.depth = o3d.geometry.Image(fg_image_depth)

    return last_frame

# %%
# 1, 14, 3, 4
# Head camera 13 was moved before processing 056
dpath = '/home/vigir3d/Datasets/cattle_scans/beef_farm_07_01/Animal_12ra/'
result_path = '/home/vigir3d/Datasets/cattle_scans/beef_farm_07_01/Animal_12ra/'
calib_path =  '/home/vigir3d/Datasets/cattle_scans/beef_farm_07_01/Animal_calib_ra/'
animal_name = os.path.basename(dpath.rstrip('/'))
print(animal_name)
success = call_cpp_program(dpath)
if not success:
    print("Failed to process MKV files with the C++ program.")
else:
    print("success!!")
    tforms = load_calibration(calib_path)
    #tforms = [np.eye(4) for _ in range(6)] #load_calibration(calib_path) # [np.eye(4) for _ in range(6)]
    file_ids = [11,12,15,19,18,20]  # exclude head cameras

    # Generate a list of volumes using list comprehension
    start = time.time()
    
    results = [process_file_list_comp(file_id, dpath, tform) for file_id, tform in zip(file_ids,tforms)]
    #o3d.visualization.draw_geometries(results)
    pcds,ptsdf = zip(*results)
    o3d.visualization.draw_geometries(ptsdf, "Uncleaned pcds")
    o3d.visualization.draw_geometries(pcds, "cleaned pcds")
    pcds_all  = combine_pcds(pcds)
    pcd_clustered = cluster_point_cloud_new(pcds_all)
    o3d.visualization.draw_geometries([pcd_clustered],"Clustered pcd")
    pcd_downsampled = pcd_clustered.voxel_down_sample(0.01)
    with o3d.utility.VerbosityContextManager(o3d.utility.VerbosityLevel.Error) as cm:
            mesh, densities = o3d.geometry.TriangleMesh.create_from_point_cloud_poisson(pcd_downsampled, depth=10)
    o3d.visualization.draw_geometries([mesh])
    sa = mesh.get_surface_area()
    if(mesh.is_watertight()):
        #print("Is watertight 1")
        v =  mesh.get_volume()
    else : 
        v = 0.0
# Out:
# Animal_12ra
# success!!

# %%
combine

# %%
pcds,ptsdf = zip(*results)
o3d.visualization.draw_geometries(ptsdf)
o3d.visualization.draw_geometries(pcds)

# %%
# 1, 14, 3, 4
# Head camera 13 was moved before processing 056
dpath = '/home/vigir3d/Datasets/cattle_scans/southwest_10_24_24/Animal_l079/'
result_path = '/home/vigir3d/Datasets/cattle_scans/southwest_10_24_24/Animal_l069/'
calib_path = '/home/vigir3d/Datasets/cattle_scans/southwest_10_24_24/Animal_calib1/'
animal_name = os.path.basename(dpath.rstrip('/'))
print(animal_name)
success = call_cpp_program(dpath)
if not success:
    print("Failed to process MKV files with the C++ program.")
else:
    print("success!!")
    tforms = [np.eye(4) for _ in range(6)] #load_calibration(calib_path) # [np.eye(4) for _ in range(6)]
    file_ids = [11,12,15,19,18,20]  # exclude head cameras

    # Generate a list of volumes using list comprehension
    start = time.time()
    
    results = [process_file_list_comp(file_id, dpath, tform) for file_id, tform in zip(file_ids,tforms)]
    o3d.visualization.draw_geometries(results)
# Out:
# Animal_l079
# success!!

# %%
o3d.io.write_point_cloud(os.path.join(result_path,animal_name+"_teaser.ply"), all_pcds)
# Out:
# True

# %%
a0 = copy.deepcopy(results[0]).transform(t02@t01)
a1 = copy.deepcopy(results[1]).transform(t02)
a3 = copy.deepcopy(results[3]).transform(t32@t34)
a4 = copy.deepcopy(results[4]).transform(t32)
a5 = copy.deepcopy(results[5]).transform(t52)

o3d.visualization.draw_geometries([a0,a1, a3, a4,a5,results[2]])
all_pcds = o3d.geometry.PointCloud()
all_pcds = a0+a1+a4+a3+a5+results[2]

# %% [markdown]
# # Trow Bridge | 09.16 plus previous week

# %%
dpath = '/home/vigir3d/Datasets/cattle_scans/southwest_10_24_24/pre_camera_move/Animal_l071/'
result_path = '/home/vigir3d/Datasets/cattle_scans/southwest_10_24_24/pre_camera_move/Animal_l071/'
calib_path = '/home/vigir3d/Datasets/cattle_scans/southwest_10_24_24/pre_camera_move/Animal_calib1/'

# %%
1, 14, 3, 4
dpath = '/home/vigir3d/Datasets/cattle_scans/trowbridge_10_02_2024/Animal_16a/'
result_path = '/home/vigir3d/Datasets/cattle_scans/trowbridge_10_02_2024/registered_cattle/'
calib_path = '/home/vigir3d/Datasets/cattle_scans/trowbridge_10_02_2024/Animal_body_calib1/'
animal_name = os.path.basename(dpath.rstrip('/'))
print(animal_name)
success = call_cpp_program(dpath)
if not success:
    print("Failed to process MKV files with the C++ program.")
else:
    print("success!!")
    tforms = load_calibration(calib_path) # [np.eye(4) for _ in range(6)]
    file_ids = [11,12,15,19,18,20]  # exclude head cameras

    # Generate a list of volumes using list comprehension
    start = time.time()
    
    results = [process_file_list_comp(file_id, dpath, tform) for file_id, tform in zip(file_ids,tforms)]
    o3d.visualization.draw_geometries(results)
#     a0 = copy.deepcopy(results[0]).transform(t02@t01)
#     a1 = copy.deepcopy(results[1]).transform(t02)
#     a3 = copy.deepcopy(results[3]).transform(t32@t34)
#     a4 = copy.deepcopy(results[4]).transform(t32)
#     a5 = copy.deepcopy(results[5]).transform(t52)

#     o3d.visualization.draw_geometries([a0,a1, a3, a4,a5,results[2]])
    #reg_animal = perform_pairwise_alignment(results)
    #o3d.io.write_point_cloud(os.path.join(dpath,animal_name+".ply"), reg_animal)
# Out:
# Animal_l071
# success!!
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[38], line 16
#      13 # Generate a list of volumes using list comprehension
#      14 start = time.time()
# ---> 16 results = [process_file_list_comp(file_id, dpath, tform) for file_id, tform in zip(file_ids,tforms)]
#      17 o3d.visualization.draw_geometries(results)
#
# Cell In[38], line 16, in <listcomp>(.0)
#      13 # Generate a list of volumes using list comprehension
#      14 start = time.time()
# ---> 16 results = [process_file_list_comp(file_id, dpath, tform) for file_id, tform in zip(file_ids,tforms)]
#      17 o3d.visualization.draw_geometries(results)
#
# Cell In[30], line 51, in process_file_list_comp(file_id, dpath, tform)
#      49 # Apply maskrcnn to filtered depth image
#      50 t1 = time.time()
# ---> 51 masked_rgbd = segment_images_modified(rgbdc)
#      52 t2 = time.time()
#      53 T = t2-t1
#
# Cell In[30], line 87, in segment_images_modified(last_frame)
#      85     mask_combined = rgb_mask
#      86 else:
# ---> 87     mask_combined = depth_mask | rgb_mask  # 1 vote arbitration (OR the masks)
#      89 # Convert tensor to numpy array and ensure the right datatype
#      90 mask_combined = mask_combined.numpy().astype(rgb_image_array.dtype)
#
# RuntimeError: The size of tensor a (1920) must match the size of tensor b (0) at non-singleton dimension 2

# %%
dpath = '/home/vigir3d/Datasets/metab_barn_data/december_collection/metab/Animal_13_2/'
result_path = '/home/vigir3d/Datasets/metab_barn_data/december_collection/registered_cattle/'
animal_name = os.path.basename(dpath.rstrip('/'))
print(animal_name)
success = call_cpp_program(dpath)
if not success:
    print("Failed to process MKV files with the C++ program.")
else:
    print("success!!")
    tforms = [np.eye(4) for _ in range(6)]
    file_ids = [11,12,14,16,17,18]  # exclude head cameras

    # Generate a list of volumes using list comprehension
    start = time.time()
    
    results = [process_file_list_comp(file_id, dpath, tform) for file_id, tform in zip(file_ids,tforms)]
    #o3d.visualization.draw_geometries(results)
    a0 = copy.deepcopy(results[0]).transform(t02@t01)
    a1 = copy.deepcopy(results[1]).transform(t02)
    a3 = copy.deepcopy(results[3]).transform(t32@t34)
    a4 = copy.deepcopy(results[4]).transform(t32)
    a5 = copy.deepcopy(results[5]).transform(t52)

    o3d.visualization.draw_geometries([a0,a1, a3, a4,a5,results[2]])
    #reg_animal = perform_pairwise_alignment(results)
    #o3d.io.write_point_cloud(os.path.join(dpath,animal_name+".ply"), reg_animal)
# Out:
# Animal_13_2
# success!!

# %%
o3d.visualization.draw_geometries([a0,a1, a3, a4,a5,results[2]])

# %%
r01,t01 = register_two_views_teaser(results[0],results[1], 0.05)
r34,t34 = register_two_views_teaser(results[3],results[4], 0.05)
r52,t52 = register_two_views_teaser(results[5],results[2], 0.05) #0.035
r32,t32 = register_two_views_teaser(r34,r52, 0.035) # |
# 0.048
r02, t02 = register_two_views_teaser(r01,r52, 0.035)
rall,tall = register_two_views_teaser(r02,r32, 0.05)
# Out:
# Extracting FPFH features
# (2784, 33)
# Computing FPFH correspondences
# FPFH generates 497 putative correspondences.
# Starting scale solver (only selecting inliers if scale estimation has been disabled).
# Scale estimation complete.
# Max core number: 83
# Num vertices: 498
# Max Clique of scale estimation inliers:
# Using chain graph for GNC rotation.
# Starting rotation solver.
# GNC rotation estimation noise bound:0.1
# GNC rotation estimation noise bound squared:0.01
# GNC-TLS solver terminated due to cost convergence.
# Cost diff: 0
# Iterations: 11
# Rotation estimation complete.
# Starting translation solver.
# Translation estimation complete.
# Extracting FPFH features
# (928, 33)
# Computing FPFH correspondences
# FPFH generates 239 putative correspondences.
# Starting scale solver (only selecting inliers if scale estimation has been disabled).
# Scale estimation complete.
# Max core number: 22
# Num vertices: 240
# Max Clique of scale estimation inliers:
# Using chain graph for GNC rotation.
# Starting rotation solver.
# GNC rotation estimation noise bound:0.1
# GNC rotation estimation noise bound squared:0.01
# GNC-TLS solver terminated due to cost convergence.
# Cost diff: 0
# Iterations: 9
# Rotation estimation complete.
# Starting translation solver.
# Translation estimation complete.
# Extracting FPFH features
# (5398, 33)
# Computing FPFH correspondences
# FPFH generates 774 putative correspondences.
# Starting scale solver (only selecting inliers if scale estimation has been disabled).
# Scale estimation complete.
# Max core number: 50
# Num vertices: 775
# Max Clique of scale estimation inliers:
# Using chain graph for GNC rotation.
# Starting rotation solver.
# GNC rotation estimation noise bound:0.1
# GNC rotation estimation noise bound squared:0.01
# GNC-TLS solver terminated due to cost convergence.
# Cost diff: 0
# Iterations: 10
# Rotation estimation complete.
# Starting translation solver.
# Translation estimation complete.
# Extracting FPFH features
# (6510, 33)
# Computing FPFH correspondences
# FPFH generates 1611 putative correspondences.
# Starting scale solver (only selecting inliers if scale estimation has been disabled).
# Scale estimation complete.
# Max core number: 62
# Num vertices: 1612
# Max Clique of scale estimation inliers:
# Using chain graph for GNC rotation.
# Starting rotation solver.
# GNC rotation estimation noise bound:0.07
# GNC rotation estimation noise bound squared:0.0049
# GNC-TLS solver terminated due to cost convergence.
# Cost diff: 0
# Iterations: 16
# Rotation estimation complete.
# Starting translation solver.
# Translation estimation complete.
# Extracting FPFH features
# (9495, 33)
# Computing FPFH correspondences
# FPFH generates 2046 putative correspondences.
# Starting scale solver (only selecting inliers if scale estimation has been disabled).
# Scale estimation complete.
# Max core number: 76
# Num vertices: 2047
# Max Clique of scale estimation inliers:
# Using chain graph for GNC rotation.
# Starting rotation solver.
# GNC rotation estimation noise bound:0.07
# GNC rotation estimation noise bound squared:0.0049
# GNC-TLS solver terminated due to cost convergence.
# Cost diff: 0
# Iterations: 9
# Rotation estimation complete.
# Starting translation solver.
# Translation estimation complete.
# Extracting FPFH features
# (10302, 33)
# Computing FPFH correspondences
# FPFH generates 2288 putative correspondences.
# Starting scale solver (only selecting inliers if scale estimation has been disabled).
# Scale estimation complete.
# Max core number: 487
# Num vertices: 2289
# Max Clique of scale estimation inliers:
# Using chain graph for GNC rotation.
# Starting rotation solver.
# GNC rotation estimation noise bound:0.1
# GNC rotation estimation noise bound squared:0.01
# GNC-TLS solver terminated due to cost convergence.
# Cost diff: 0
# Iterations: 13
# Rotation estimation complete.
# Starting translation solver.
# Translation estimation complete.

# %%
o3d.visualization.draw_geometries([rall])

# %%
print(animal_name)
print(result_path)
# Out:
# Animal_16a
# /home/vigir3d/Datasets/cattle_scans/trowbridge_10_02_2024/registered_cattle/

# %%
o3d.io.write_point_cloud(os.path.join(result_path,animal_name+"_teaser.ply"), rall)
# Out:
# [Open3D WARNING] Write Ply clamped color value to valid range
# True

# %%
path = '/home/vigir3d/Datasets/metab_barn_data/december_collection/registered_cattle/'
pcd = o3d.io.read_point_cloud(os.path.join(path, 'Animal_1_3_cleaned.ply'))
o3d.visualization.draw_geometries([pcd])

# %%
print('run Poisson surface reconstruction')
with o3d.utility.VerbosityContextManager(
        o3d.utility.VerbosityLevel.Debug) as cm:
    poisson_mesh, densities = o3d.geometry.TriangleMesh.create_from_point_cloud_poisson(
        pcd, depth=10)
#print(poisson_mesh)
poisson_mesh.get_surface_area()
#o3d.visualization.draw_geometries([poisson_mesh])
# Out:
# run Poisson surface reconstruction
# [Open3D DEBUG] Input Points / Samples: 186660 / 171352
# [Open3D DEBUG] #   Got kernel density: 0.12497496604919434 (s), 2919.2421875 (MB) / 2919.2421875 (MB) / 4828 (MB)
# [Open3D DEBUG] #     Got normal field: 0.24117398262023926 (s), 2919.7578125 (MB) / 2919.7578125 (MB) / 4828 (MB)
# [Open3D DEBUG] Point weight / Estimated Area: 1.491336e-05 / 2.783728e+00
# [Open3D DEBUG] #       Finalized tree: 0.30677318572998047 (s), 2920.2734375 (MB) / 2920.2734375 (MB) / 4828 (MB)
# [Open3D DEBUG] #  Set FEM constraints: 0.3849799633026123 (s), 2920.2734375 (MB) / 2920.2734375 (MB) / 4828 (MB)
# [Open3D DEBUG] #Set point constraints: 0.11272478103637695 (s), 2920.2734375 (MB) / 2920.2734375 (MB) / 4828 (MB)
# [Open3D DEBUG] Leaf Nodes / Active Nodes / Ghost Nodes: 3194836 / 2114344 / 1536897
# [Open3D DEBUG] Memory Usage: 2920.273 MB
# Cycle[0] Depth[0/6]:	Updated constraints / Got system / Solved in:  0.000 /  0.000 /  0.000	(2911.566 MB)	Nodes: 8
# CG: 5.9396e-01 -> 5.9396e-01 -> 2.2337e-05 (3.8e-05) [32722]
# Cycle[0] Depth[1/6]:	Updated constraints / Got system / Solved in:  0.000 /  0.000 /  0.000	(2911.566 MB)	Nodes: 27
#   GS: 1.4761e+00 -> 1.4761e+00 -> 5.1162e-04 (3.5e-04) [8]
# Cycle[0] Depth[2/6]:	Updated constraints / Got system / Solved in:  0.000 /  0.000 /  0.000	(2911.566 MB)	Nodes: 125
#     GS: 1.6948e+00 -> 1.6948e+00 -> 1.5713e-02 (9.3e-03) [8]
# Cycle[0] Depth[3/6]:	Updated constraints / Got system / Solved in:  0.000 /  0.001 /  0.000	(2911.566 MB)	Nodes: 729
#       GS: 1.7426e+00 -> 1.7426e+00 -> 1.4861e-02 (8.5e-03) [8]
# Cycle[0] Depth[4/6]:	Updated constraints / Got system / Solved in:  0.000 /  0.003 /  0.001	(2911.566 MB)	Nodes: 4913
#         GS: 1.6678e+00 -> 1.6678e+00 -> 1.3719e-02 (8.2e-03) [8]
# Cycle[0] Depth[5/6]:	Updated constraints / Got system / Solved in:  0.001 /  0.006 /  0.008	(2911.566 MB)	Nodes: 35937
#           GS: 1.2066e+00 -> 1.2066e+00 -> 8.4205e-03 (7.0e-03) [8]
# Cycle[0] Depth[6/6]:	Updated constraints / Got system / Solved in:  0.000 /  0.007 /  0.007	(2911.566 MB)	Nodes: 29872
#             GS: 5.9594e-01 -> 5.9594e-01 -> 9.9312e-04 (1.7e-03) [8]
# Cycle[0] Depth[0/8]:	Updated constraints / Got system / Solved in:  0.000 /  0.000 /  0.000	(2912.211 MB)	Nodes: 8
# CG: 6.7243e-01 -> 6.7243e-01 -> 2.3225e-05 (3.5e-05) [32722]
# Cycle[0] Depth[1/8]:	Updated constraints / Got system / Solved in:  0.000 /  0.000 /  0.000	(2912.211 MB)	Nodes: 27
#   GS: 1.6065e+00 -> 1.6065e+00 -> 3.9079e-04 (2.4e-04) [8]
# Cycle[0] Depth[2/8]:	Updated constraints / Got system / Solved in:  0.000 /  0.000 /  0.000	(2912.211 MB)	Nodes: 125
#     GS: 1.8111e+00 -> 1.8111e+00 -> 1.5234e-02 (8.4e-03) [8]
# Cycle[0] Depth[3/8]:	Updated constraints / Got system / Solved in:  0.000 /  0.001 /  0.000	(2912.211 MB)	Nodes: 729
#       GS: 1.9164e+00 -> 1.9164e+00 -> 1.5668e-02 (8.2e-03) [8]
# Cycle[0] Depth[4/8]:	Upda[Open3D DEBUG] # Linear system solved: 0.7465009689331055 (s), 2920.2734375 (MB) / 2920.2734375 (MB) / 4828 (MB)
# ted constraints / Got system / Solved in:  0.000 /  0.003 /  0.001	(2912.211 MB)	Nodes: 4913
#         GS: 1.9395e+00 -> 1.9395e+00 -> 1.4885e-02 (7.7e-03) [8]
# Cycle[0] Depth[5/8]:	Updated constraints / Got system / Solved in:  0.001 /  0.006 /  0.007	(2912.211 MB)	Nodes: 35937
#           GS: 1.7374e+00 -> 1.7374e+00 -> 9.4191e-03 (5.4e-03) [8]
# Cycle[0] Depth[6/8]:	Updated constraints / Got system / Solved in:  0.001 /  0.008 /  0.011	(2912.211 MB)	Nodes: 62836
#             GS: 1.3560e+00 -> 1.3560e+00 -> 8.8842e-03 (6.6e-03) [8]
# Cycle[0] Depth[7/8]:	Updated constraints / Got system / Solved in:  0.003 /  0.020 /  0.025	(2912.211 MB)	Nodes: 204304
#               GS: 9.3280e-01 -> 9.3280e-01 -> 8.4892e-03 (9.1e-03) [8]
# Cycle[0] Depth[8/8]:	Updated constraints / Got system / Solved in:  0.006 /  0.051 /  0.062	(2912.211 MB)	Nodes: 512432
#                 GS: 5.3810e-01 -> 5.3810e-01 -> 1.8319e-03 (3.4e-03) [8]
# Cycle[0] Depth[ 0/10]:	Updated constraints / Got system / Solved in:  0.000 /  0.000 /  0.000	(2920.273 MB)	Nodes: 8
# CG: 9.8859e-01 -> 9.8859e-01 -> 3.2627e-05 (3.3e-05) [32722]
# Cycle[0] Depth[ 1/10]:	Updated constraints / Got system / Solved in:  0.000 /  0.000 /  0.000	(2920.273 MB)	Nodes: 27
#   GS: 2.4847e+00 -> 2.4847e+00 -> 2.2015e-04 (8.9e-05) [8]
# Cycle[0] Depth[ 2/10]:	Updated constraints / Got system / Solved in:  0.002 /  0.002 /  0.000	(2920.273 MB)	Nodes: 125
#     GS: 2.9391e+00 -> 2.9391e+00 -> 1.9978e-02 (6.8e-03) [8]
# Cycle[0] Depth[ 3/10]:	Updated constraints / Got system / Solved in:  0.000 /  0.001 /  0.000	(2920.273 MB)	Nodes: 729
#       GS: 3.2668e+00 -> 3.2668e+00 -> 2.4227e-02 (7.4e-03) [8]
# Cycle[0] Depth[ 4/10]:	Updated constraints / Got system / Solved in:  0.000 /  0.006 /  0.001	(2920.273 MB)	Nodes: 4913
#         GS: 3.1583e+00 -> 3.1583e+00 -> 2.3059e-02 (7.3e-03) [8]
# Cycle[0] Depth[ 5/10]:	Updated constraints / Got system / Solved in:  0.001 /  0.007 /  0.007	(2920.273 MB)	Nodes: 35937
#           GS: 2.7933e+00 -> 2.7933e+00 -> 1.5790e-02 (5.7e-03) [8]
# Cycle[0] Depth[ 6/10]:	Updated constraints / Got system / Solved in:  0.001 /  0.009 /  0.[Open3D DEBUG] Got average: 0.020626068115234375 (s), 2920.2734375 (MB) / 2920.2734375 (MB) / 4828 (MB)
# [Open3D DEBUG] Iso-Value: 4.939556e-01 = 9.220175e+04 / 1.866600e+05
# [Open3D DEBUG] #          Total Solve:       6.2 (s),    2937.6 (MB)
# 4.669644738608338

# %%
o3d.visualization.draw_geometries([poisson_mesh])

# %%
poisson_mesh.get_surface_area()
# Out:
# 4.669644738608338

# %%
rec_mesh.get_surface_area()
# Out:
# 4.383493459450811

# %%
mesh.get_surface_area()
# Out:
# 6.606693488130971

# %%
alpha = 0.010
print(f"alpha={alpha:.3f}")
mesh = o3d.geometry.TriangleMesh.create_from_point_cloud_alpha_shape(pcd, alpha)
mesh.compute_vertex_normals()
o3d.visualization.draw_geometries([mesh], mesh_show_back_face=True)
# Out:
# alpha=0.010

# %%
o3d.visualization.draw_geometries([rec_mesh])

# %%
radii = [0.005, 0.01, 0.02, 0.04]
rec_mesh = o3d.geometry.TriangleMesh.create_from_point_cloud_ball_pivoting(
    pcd, o3d.utility.DoubleVector(radii))
o3d.visualization.draw_geometries([pcd, rec_mesh])

# %% [markdown]
# # Transform PointClouds into 1 coordinate frame | Beef Farm 05.15.2024

# %%
# construct transform matrices
H0 = t12 @ t01
H1 = t12
H3 = t32
H4 = H3 @ np.linalg.inv(t34)
H5 = t52

# apply transformations
p0 = copy.deepcopy(results[0]).transform(H0)
p1 = copy.deepcopy(results[1]).transform(H1)
p3 = copy.deepcopy(results[3]).transform(H3)
p4 = copy.deepcopy(results[4]).transform(H4)
p5 = copy.deepcopy(results[5]).transform(H5)
o3d.visualization.draw_geometries([p0,p1,p3,p4,p5,results[2]])
pcd_all = o3d.geometry.PointCloud()
pcd_all = p0+p1+p3+p4+p5+results[2]

# %% [markdown]
# # Processing Thompson Research Center

# %%
# 2a, 13d, 15a,16a
# 12d, 14d, 3, 1d,4a,5c,8c, 9e
base_path = '/home/vigir3d/Datasets/cattle_scans/thompson4/'
calib_path = os.path.join(base_path,'Animal_calib_1/')
result_path = os.path.join(base_path,'registered_cattle/')
x = os.listdir(base_path)
to_skip = {'registered_cattle', 'registered_head','readme.txt'}
filtered_animal_list = [item for item in x if item not in to_skip]
ctr = 0

print("Processing: ",len(filtered_animal_list), " animals...")
processed_animals = os.listdir(result_path)

for current_animal in filtered_animal_list : 
    current_animal = current_animal + '/' 
    dpath = os.path.join(base_path,current_animal)
    animal_name = os.path.basename(dpath.rstrip('/'))
    animal_fname = os.path.basename(current_animal.rstrip('/'))
    file_name = animal_fname+"_teaser.ply"

    if animal_fname == "Animal_j40":
        print("Skipping file: ", animal_fname)
        continue
    if file_name in processed_animals:
        print(file_name, " has been processed!")
        continue
    else :
        print("Processing: ", file_name)
        success = call_cpp_program(dpath)
        if not success:
            print("Failed to process MKV files with the C++ program.")
        else:
            #print("success!!")
            #tforms = load_calibration(calib_path)
            tforms = [np.eye(4) for _ in range(6)]
            file_ids = [11,12,15,19,18,20]  # exclude head cameras

            results = [process_file_list_comp(file_id, dpath, tform) for file_id, tform in zip(file_ids,tforms)]
            a0 = copy.deepcopy(results[0]).transform(t02@t01)
            a1 = copy.deepcopy(results[1]).transform(t02)
            a3 = copy.deepcopy(results[3]).transform(t32@t34)
            a4 = copy.deepcopy(results[4]).transform(t32)
            a5 = copy.deepcopy(results[5]).transform(t52)

            #o3d.visualization.draw_geometries([a0,a1, a3, a4,a5,results[2]])
            pcd_all = o3d.geometry.PointCloud()
            pcd_all = a0+a1+a3+a4+a5+results[2]

            if ctr % 20 == 0:
                print("Current Iteration: ", ctr)
                o3d.visualization.draw_geometries([pcd_all])
            #print(animal_fname)
            o3d.io.write_point_cloud(os.path.join(result_path,file_name), pcd_all)
    ctr+=1
# Out:
# Processing:  133  animals...
# Animal_h86_teaser.ply  has been processed!
# Animal_h105_teaser.ply  has been processed!
# Animal_f168_teaser.ply  has been processed!
# Animal_j171_teaser.ply  has been processed!
# Animal_h34_teaser.ply  has been processed!
# Animal_k57_teaser.ply  has been processed!
# Animal_j24_teaser.ply  has been processed!
# Animal_h74_teaser.ply  has been processed!
# Animal_k209_teaser.ply  has been processed!
# Animal_j191_teaser.ply  has been processed!
# Animal_k118_teaser.ply  has been processed!
# Animal_h190_teaser.ply  has been processed!
# Animal_h48_teaser.ply  has been processed!
# Animal_k65_teaser.ply  has been processed!
# Animal_k83_teaser.ply  has been processed!
# Animal_h202_teaser.ply  has been processed!
# Animal_h12_teaser.ply  has been processed!
# Animal_k123_teaser.ply  has been processed!
# Animal_j189_teaser.ply  has been processed!
# Animal_j90_teaser.ply  has been processed!
# Animal_h61_teaser.ply  has been processed!
# Animal_g53_teaser.ply  has been processed!
# Animal_k34_teaser.ply  has been processed!
# Animal_k176_teaser.ply  has been processed!
# Animal_k119_teaser.ply  has been processed!
# Animal_j96_teaser.ply  has been processed!
# Animal_j59_teaser.ply  has been processed!
# Animal_h85_teaser.ply  has been processed!
# Animal_y7_teaser.ply  has been processed!
# Animal_x118_teaser.ply  has been processed!
# Animal_h33_teaser.ply  has been processed!
# Animal_h160_teaser.ply  has been processed!
# Animal_k3_teaser.ply  has been processed!
# Animal_j138_teaser.ply  has been processed!
# Animal_x100_teaser.ply  has been processed!
# Animal_h177_teaser.ply  has been processed!
# Animal_j157_teaser.ply  has been processed!
# Animal_j30_teaser.ply  has been processed!
# Animal_j170_teaser.ply  has been processed!
# Animal_k194_teaser.ply  has been processed!
# Animal_y192_teaser.ply  has been processed!
# Animal_k189_teaser.ply  has been processed!
# Animal_k12_teaser.ply  has been processed!
# Animal_j85_teaser.ply  has been processed!
# Animal_e113_teaser.ply  has been processed!
# Animal_y7d_teaser.ply  has been processed!
# Animal_j150_teaser.ply  has been processed!
# Animal_j14_teaser.ply  has been processed!
# Animal_k99_teaser.ply  has been processed!
# Animal_j119_teaser.ply  has been processed!
# Animal_j162_teaser.ply  has been processed!
# Animal_j128_teaser.ply  has been processed!
# Animal_y73_teaser.ply  has been processed!
# Animal_k127_a_teaser.ply  has been processed!
# Animal_k124_teaser.ply  has been processed!
# Animal_j72_teaser.ply  has been processed!
# Animal_j34_teaser.ply  has been processed!
# Animal_k2_teaser.ply  has been processed!
# Animal_k180_teaser.ply  has been processed!
# Animal_h7_teaser.ply  has been processed!
# Animal_d70_teaser.ply  has been processed!
# Animal_h189_teaser.ply  has been processed!
# Animal_k52_teaser.ply  has been processed!
# Animal_h191_teaser.ply  has been processed!
# Animal_k63_teaser.ply  has been processed!
# Animal_k106_teaser.ply  has been processed!
# Animal_j10_teaser.ply  has been processed!
# Animal_j21_teaser.ply  has been processed!
# Animal_k134_teaser.ply  has been processed!
# Animal_h188_teaser.ply  has been processed!
# Animal_k76_teaser.ply  has been processed!
# Animal_k27_teaser.ply  has been processed!
# Animal_c120_teaser.ply  has been processed!
# Animal_z146_teaser.ply  has been processed!
# Animal_j6_teaser.ply  has been processed!
# Animal_j175_teaser.ply  has been processed!
# Animal_j154_teaser.ply  has been processed!
# Animal_d66_teaser.ply  has been processed!
# Animal_j79_teaser.ply  has been processed!
# Animal_h162_teaser.ply  has been processed!
# Animal_k201_teaser.ply  has been processed!
# Animal_k98_teaser.ply  has been processed!
# Animal_k17_teaser.ply  has been processed!
# Animal_j58_teaser.ply  has been processed!
# Animal_j56_teaser.ply  has been processed!
# Animal_k175_teaser.ply  has been processed!
# Animal_j26_teaser.ply  has been processed!
# Animal_h197_teaser.ply  has been processed!
# Animal_e122_teaser.ply  has been processed!
# Animal_h73_teaser.ply  has been processed!
# Animal_h84_teaser.ply  has been processed!
# Animal_h118_teaser.ply  has been processed!
# Animal_f169_teaser.ply  has been processed!
# Skipping file:  Animal_j40
# Animal_h68_teaser.ply  has been processed!
# Processing:  Animal_y32_teaser.ply
# Current Iteration:  0
# Processing:  Animal_h17_teaser.ply
# Processing:  Animal_j148_teaser.ply
# Processing:  Animal_f135_teaser.ply
# Processing:  Animal_h104_teaser.ply
# Processing:  Animal_y72_teaser.ply
# Processing:  Animal_d57_teaser.ply
# Processing:  Animal_g70_teaser.ply
# Processing:  Animal_k82_teaser.ply
# Processing:  Animal_h119_teaser.ply
# Processing:  Animal_k88_teaser.ply
# Processing:  Animal_k102_teaser.ply
# Processing:  Animal_j144_teaser.ply
# Processing:  Animal_g63_teaser.ply
# Processing:  Animal_k110_teaser.ply
# Processing:  Animal_b2_teaser.ply
# Processing:  Animal_k94_teaser.ply
# Processing:  Animal_h158_teaser.ply
# Processing:  Animal_j131_teaser.ply
# [Open3D WARNING] Write Ply clamped color value to valid range
# Processing:  Animal_j44_teaser.ply
# Processing:  Animal_h82_teaser.ply
# Current Iteration:  20
# Processing:  Animal_j187_teaser.ply
# Processing:  Animal_k131_teaser.ply
# Processing:  Animal_k56_teaser.ply
# Processing:  Animal_k178_teaser.ply
# Processing:  Animal_k37_teaser.ply
# Processing:  Animal_d86_teaser.ply
# Processing:  Animal_h15_teaser.ply
# Processing:  Animal_j163_teaser.ply
# Processing:  Animal_k31_teaser.ply
# Processing:  Animal_k111_teaser.ply
# Processing:  Animal_j78_teaser.ply
# Processing:  Animal_h83_teaser.ply
# Processing:  Animal_h217_teaser.ply
# Processing:  Animal_k66_teaser.ply
# Processing:  Animal_h59_teaser.ply
# [Open3D WARNING] Write Ply clamped color value to valid range
# Processing:  Animal_j43_teaser.ply
# Processing:  Animal_h95_teaser.ply

# %% [markdown]
# # Processing Beef Farm Data 07.15.2024

# %%
# 0a-b, 10a-f, 11a-b, 7a-c
calib_path = '/home/vigir3d/Datasets/cattle_scans/beef_farm_07_15_24/Animal_cal_body/'
dpath = '/home/vigir3d/Datasets/cattle_scans/beef_farm_07_15_24/Animal_11a/'
result_path = '/home/vigir3d/Datasets/cattle_scans/beef_farm_07_15_24/registered_cattle/'
animal_name = os.path.basename(dpath.rstrip('/'))
print(animal_name)
success = call_cpp_program(dpath)
if not success:
    print("Failed to process MKV files with the C++ program.")
else:
    print("success!!")
    tforms = load_calibration(calib_path)
    file_ids = [11,12,15,19,18,20]  # exclude head cameras

    # Generate a list of volumes using list comprehension
    start = time.time()
    
    results = [process_file_list_comp(file_id, dpath, tform) for file_id, tform in zip(file_ids,tforms)]
    o3d.visualization.draw_geometries(results)
    #reg_animal = perform_pairwise_alignment(results)
    #o3d.io.write_point_cloud(os.path.join(dpath,animal_name+".ply"), reg_animal)
# Out:
# Animal_11a
# success!!

# %%
o3d.visualization.draw_geometries([r02, r32])

# %%
print(vs_list)
# Out:
# [0.05]

# %%
#r01,t01 = register_two_views_teaser(results[0],results[1], 0.05)
#r34,t34 = register_two_views_teaser(results[3],results[4], 0.05)
# vs_list = []
# for vs in np.arange(0.047,0.05, 0.001):
#     r52,t52 = register_two_views_teaser(results[5],results[2], vs) #0.035
#     print(vs)
#     num = int(input("good?: "))
#     if num == 1 :
#         vs_list.append(vs)
#         break
    
r32,t32 = register_two_views_teaser(r34,r52, 0.035) # |
#    print(vs)
#r02, t02 = register_two_views_teaser(r01,r52, 0.033)
#rall,tall = register_two_views_teaser(r02,r32, 0.05)
# Out:
# Extracting FPFH features
# (6600, 33)
# Computing FPFH correspondences
# FPFH generates 1243 putative correspondences.
# Starting scale solver (only selecting inliers if scale estimation has been disabled).
# Scale estimation complete.
# Max core number: 52
# Num vertices: 1244
# Max Clique of scale estimation inliers:
# Using chain graph for GNC rotation.
# Starting rotation solver.
# GNC rotation estimation noise bound:0.07
# GNC rotation estimation noise bound squared:0.0049
# GNC-TLS solver terminated due to cost convergence.
# Cost diff: 0
# Iterations: 21
# Rotation estimation complete.
# Starting translation solver.
# Translation estimation complete.

# %%
# Apply tforms |
# Need H0, H1, H3, H4, H5
H0 = t02 @ t01
H1 = t02
H3 = t32 @ t34
H4 = t32 
H5 = t52
a0 = copy.deepcopy(results[0]).transform(H0)
a1 = copy.deepcopy(results[1]).transform(H1)
a3 = copy.deepcopy(results[3]).transform(H3)
a4 = copy.deepcopy(results[4]).transform(H4)
a5 = copy.deepcopy(results[5]).transform(H5)

o3d.visualization.draw_geometries([a0,a1,results[2],a3,a4,a5])

# %%
o3d.visualization.draw_geometries([rall])
animal_fname = os.path.basename(animal_name.rstrip('/'))
#print(animal_fname)
file_name = animal_fname+"_teaser.ply"
result_path = '/home/vigir3d/Datasets/cattle_scans/beef_farm_07_15_24/registered_cattle/'

print(file_name)
# Out:
# Animal_10a_teaser.ply

# %%
o3d.io.write_point_cloud(os.path.join(result_path,file_name), rall)
# Out:
# [Open3D WARNING] Write Ply clamped color value to valid range
# True

# %% [markdown]
# # Processing Metab Barn Data 03.13.2024

# %%
calib_path = '/home/vigir3d/Datasets/cattle_scans/metab_03_15_24/tmp/Animal_cal3/'
dpath = '/home/vigir3d/Datasets/cattle_scans/metab_03_15_24/Animal_4b/'
animal_name = os.path.basename(dpath.rstrip('/'))
print(animal_name)
success = call_cpp_program(dpath)
if not success:
    print("Failed to process MKV files with the C++ program.")
else:
    print("success!!")
    tforms = load_calibration(calib_path)
    file_ids = [11,12,15,19,18,20]  # exclude head cameras

    # Generate a list of volumes using list comprehension
    start = time.time()
    
    results = [process_file_list_comp(file_id, dpath, tform) for file_id, tform in zip(file_ids,tforms)]
    o3d.visualization.draw_geometries(results)
    reg_animal = perform_pairwise_alignment(results)
    o3d.io.write_point_cloud(os.path.join(dpath,animal_name+".ply"), reg_animal)

# %%
draw_registration_result(results[0],results[1],np.eye(4))
draw_registration_result(results[5],results[2],np.eye(4))
draw_registration_result(results[4],results[3],np.eye(4))
draw_registration_result(results[1],results[2],np.eye(4))
draw_registration_result(results[3],results[2],np.eye(4))

# %% [markdown]
# # PROCESS DISTANCE SURFACE AREA MEASURES

# %%
dpath = '/home/vigir3d/Datasets/object_distance_SA/'
animal_name = os.path.basename(dpath.rstrip('/'))
print(animal_name)
if not success:
    print("Failed to process MKV files with the C++ program.")
else:
    print("success!!")
    tforms = load_calibration(calib_path)
    file_ids = [11,12,15,19,18,20]  # exclude head cameras

    # Generate a list of volumes using list comprehension
    start = time.time()
    
    results = [process_file_list_comp(file_id, dpath, tform) for file_id, tform in zip(file_ids,tforms)]
    o3d.visualization.draw_geometries(results)
    reg_animal = perform_pairwise_alignment(results)
    o3d.io.write_point_cloud(os.path.join(dpath,animal_name+".ply"), reg_animal)

# %%
o3d.io.write_point_cloud(os.path.join(dpath,"Animal_12ra.ply"), reg_a12)

# %%
def perform_pairwise_alignment(pcds_tsdf):
    """Compute and apply transformations."""
    t01 = colored_ICP(pcds_tsdf[0], pcds_tsdf[1])
    t52 = colored_ICP(pcds_tsdf[5], pcds_tsdf[2])
    t43 = colored_ICP(pcds_tsdf[4], pcds_tsdf[3])
    t12 = colored_ICP(pcds_tsdf[1], pcds_tsdf[2])
    t32 = colored_ICP(pcds_tsdf[3], pcds_tsdf[2])

    H0 = t12 @ t01
    H1 = t12
    H3 = t32
    H4 = t32 @ t43
    H5 = t52

    # Transform the point clouds
    p0 = copy.deepcopy(pcds_tsdf[0]).transform(H0)
    p1 = copy.deepcopy(pcds_tsdf[1]).transform(H1)
    p3 = copy.deepcopy(pcds_tsdf[3]).transform(H3)
    p4 = copy.deepcopy(pcds_tsdf[4]).transform(H4)
    p5 = copy.deepcopy(pcds_tsdf[5]).transform(H5)
    o3d.visualization.draw_geometries([p0,p1,p3,p4,p5,pcds_tsdf[2]])
    pcd_all = o3d.geometry.PointCloud()
    pcd_all = p0+p1+p3+p4+p5+pcds_tsdf[2]
    
    return pcd_all

# %%
o3d.visualization.draw_geometries(results)

# %%
cal_fil_path = '/home/vigir3d/Datasets/cattle_scans/metab_03_15_24/tmp/Animal_cal3/'
H40 = np.loadtxt(cal_fil_path+"H_0_4.txt")
H30 = np.loadtxt(cal_fil_path+"H_0_3.txt")

# %%
pt1 = copy.deepcopy

# %%
o3d.visualization.draw_geometries([pcds[4],pcds[3]])

# %%
data_path='/home/vigir3d/Software/programs/Depth-Anything/metric_depth/input_data_frame/'
pcds_dam = load_pcds(data_path)

# %%
o3d.visualization.draw_geometries([pcds_dam[0]])

# %%
pds = [pcds_dam[0], pcds_dam[1],pcds_dam[4],pcds_dam[7],pcds_dam[8],pcds_dam[9]]

# %%
# Direct transformations
p1 = copy.deepcopy(pds[1]).transform(t12) # Camera 1 to Camera 2

# For pcds[0], transform to Camera 1's frame, then to Camera 2's frame
t02 = t01 @ t12 # Matrix multiplication
p0 = copy.deepcopy(pds[0]).transform(t02)

# pcds[2] is already in Camera 2's frame

# For pcds[5], invert t25 to transform to Camera 2's frame
t25_inv = np.linalg.inv(t25)
p5 = copy.deepcopy(pds[5]).transform(t25_inv)

# For pcds[4], transform to Camera 5's frame, then to Camera 2's frame
t45_inv = np.linalg.inv(t45)
t24 = t45_inv @ t25_inv # Matrix multiplication
p4 = copy.deepcopy(pds[4]).transform(t24)

# For pcds[3], transform to Camera 4's frame, then to Camera 5's frame, then to Camera 2's frame
t35 = t34 @ t45
t23 = t35 @ t25_inv # Matrix multiplication
p3 = copy.deepcopy(pds[3]).transform(t23)

# %%
o3d.visualization.draw_geometries([p0,p1,pds[2],p3,p4,p5])

# %%
o3d.visualization.draw_geometries([p0,p1])

# %%
# Direct transformations
p1 = copy.deepcopy(pcds[1]).transform(t12) # Camera 1 to Camera 2

# For pcds[0], transform to Camera 1's frame, then to Camera 2's frame
t02 = t01 @ t12 # Matrix multiplication
p0 = copy.deepcopy(pcds[0]).transform(t02)

# pcds[2] is already in Camera 2's frame

# For pcds[5], invert t25 to transform to Camera 2's frame
t25_inv = np.linalg.inv(t25)
p5 = copy.deepcopy(pcds[5]).transform(t25_inv)

# For pcds[4], transform to Camera 5's frame, then to Camera 2's frame
t45_inv = np.linalg.inv(t45)
t24 = t45_inv @ t25_inv # Matrix multiplication
p4 = copy.deepcopy(pcds[4]).transform(t24)

# For pcds[3], transform to Camera 4's frame, then to Camera 5's frame, then to Camera 2's frame
t35 = t34 @ t45
t23 = t35 @ t25_inv # Matrix multiplication
p3 = copy.deepcopy(pcds[3]).transform(t23)

# %%
o3d.visualization.draw_geometries([p0,p1,pcds[2],p3,p4,p5])

# %%
pcd_combined = o3d.geometry.PointCloud()
pcd_combined=p0+p1+pcds[2]+p3+p4+p5
o3d.visualization.draw_geometries([pcd_combined])

# %%
pwd

# %%
np.savetxt("H34_a16B_wireframe.txt",t34)

# %%
o3d.visualization.draw_geometries([pcds[0]])

# %%
o3d.io.write_point_cloud("Animal_16b_wireframe.ply",pcd_combined)

# %%
pac,tac =register_two_views_teaser(p34,p01,0.05)

# %%
pcds = load_pcds(os.getcwd())

# %%
p01, t01 = register_two_views_teaser(pcds[0],pcds[1],0.05)
p12, t12 = register_two_views_teaser(pcds[1],pcds[2],0.05)
p25, t25 = register_two_views_teaser(pcds[2],pcds[5],0.05)
p45, t45 = register_two_views_teaser(pcds[4],pcds[5],0.05)
p34, t34 = register_two_views_teaser(pcds[3],pcds[4],0.05)

# %%
p01, t01 = register_two_views_teaser(pcds[0],pcds[1],0.05)
p12, t12 = register_two_views_teaser(pcds[1],pcds[2],0.05)

# %%
p45, t45 = register_two_views_teaser(pcds[4],pcds[5],0.05)
p34, t34 = register_two_views_teaser(pcds[3],pcds[4],0.05)

# %%
draw_registration_result(pcds[3],pcds[4],np.eye(4))

# %%
def load_pcds(path):
    print(path)
    files = glob.glob(path+"/Animal*.ply")
    files.sort()
    print(files)
    pcds = [o3d.io.read_point_cloud(file) for file in files]
    return pcds

# %%
def load_tforms_teaser():
    dpath = '/home/vigir3d/Datasets/cattle_scans/Cattle_11_17_22/Animal_1_1/'


    r01 = np.loadtxt(dpath+"r01.txt" )
    r12 = np.loadtxt(dpath+"r12_0031.txt")
    r32 = np.loadtxt(dpath+"r32_0026.txt")
    r52 = np.loadtxt(dpath+"r52_005.txt")
    r43 = np.loadtxt(dpath+"r43_0031.txt")

    h0 = r12@r01
    h1 = r12
    h3 = r32
    h4 = r32@r43
    h5 = r52
    return [h0,h1,np.eye(4),h3,h4,h5]
#     a0 = copy.deepcopy(pcds[0]).transform(h0)
#     a1 = copy.deepcopy(pcds[1]).transform(h1)
#     a2 = copy.deepcopy(pcds[2]).transform(np.eye(4))
#     a3 = copy.deepcopy(pcds[3]).transform(h3)
#     a4 = copy.deepcopy(pcds[4]).transform(h4)
#     a5 = copy.deepcopy(pcds[5]).transform(h5)
#     return [a0,a1,a2, a3,a4,a5]

# %%
path = '/home/vigir3d/Datasets/cattle_scans/Cattle_11_17_22/Animal_11_1/'
pcds = load_pcds(path)

# %%
o3d.visualization.draw_geometries(pcds)

# %%
s = time.time()
rgb_model_path = '/home/vigir3d/Datasets/cattle_scans/maskrcnn_data/maskrcnn_v2.pth'
depth_model_path = '/home/vigir3d/Datasets/cattle_scans/maskrcnn_data/maskrcnn_depth_best.pth'
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Loads the maskrcnn trained for depth and rgb
model_rgb = load_maskrcnn_model(rgb_model_path)
model_depth = load_maskrcnn_model(depth_model_path)


transform = T.ToTensor()
# These two will need to be requested from command line
# -i   | input data path
# - t  | calibration data path 
dpath = '/home/vigir3d/Datasets/cattle_scans/Cattle_11_17_22/Animal_18_1/'


s1 = time.time()
success = call_cpp_program(dpath)
s2 = time.time()

if not success:
    print("Failed to process MKV files with the C++ program.")
else:
    print("success!!")
    print("Load Duration: ", s2-s1, "s")
    #dpath = '/home/vigir3d/Datasets/cattle_scans/farm_scan1/Animal_482_2/'
  
    tforms = load_tforms_teaser()
    file_ids = [11,12,14,16,17,18]  # exclude head cameras

    # Generate a list of volumes using list comprehension
    start = time.time()
    
    results = [process_file_list_comp(file_id, dpath, tform) for file_id, tform in zip(file_ids,tforms)]
    pcds,ptsdf = zip(*results)
    end = time.time()

    # For now, no need to do registration .. Just transform
    r1 = time.time()
    #pcd_all, ptsdf_all = perform_pairwise_alignment(ptsdf,pcds)
    pcd_all = combine_pcds(pcds)
    ptsdf_all = combine_pcds(ptsdf)
    r2 = time.time()

    p1 = time.time()
    # cluster first to remove extra noise
    pcd_clustered = cluster_point_cloud_new(pcd_all)
    # After clustering, we upsample from the initial
    p2 = time.time()

    u1 = time.time()
    pcd_upsampled = upsample_using_reference_normals_new(pcd_clustered, ptsdf_all)
    u2 = time.time()

    tn1 = time.time()
    pcd_downsampled = pcd_upsampled.voxel_down_sample(0.01)
    #pcd_downsampled.orient_normals_towards_camera_location()
    #pcd_downsampled.orient_normals_consistent_tangent_plane(30)
    tn2 = time.time()

    m1 = time.time()
    with o3d.utility.VerbosityContextManager(o3d.utility.VerbosityLevel.Error) as cm:
            mesh, densities = o3d.geometry.TriangleMesh.create_from_point_cloud_poisson(pcd_downsampled, depth=6)

    sa = mesh.get_surface_area()
    if(mesh.is_watertight()):
        #print("Is watertight 1")
        v =  mesh.get_volume()
    else : 
        v = 0.0
    m2 = time.time()
    animal_id = os.path.basename(os.path.normpath(dpath))
    save_results(animal_id, dpath, mesh, pcd_downsampled, sa, v)

    e = time.time()
    print(f'Total time spent maskrcnn segmentation: {globT:.2f} seconds')
    globT = 0


    print("Load and Segment Duration: ", end-start, "s")

    print("Register clouds: ", r2-r1, " s")

    print("Clustering: ", p2-p1, " s")

    print("Upsampling: ", u2-u1, " s")
    print("Down Sampling: ", tn2-tn1, " s")    
    print("Meshing: ", m2-m1, " s")
    print("Total time: ", e-s, " s")

# %%
dpath

# %%
def process_file_list_comp_v2(file_id, dpath,tform): # This applies flying pixel filter to unmaskrcnn'd data
    global globT
    ws = 2
    # Format filenames
    dpath = dpath.rstrip('/')

    # Split by the directory separator and get the last part
    suffix = os.path.basename(dpath)
    
    file_suffix = suffix + "_nano_" + str(file_id)
    # Construct full file paths using os.path.join for better cross-platform compatibility
    depth_file = os.path.join(dpath, file_suffix + "_depth.png")
    color_file = os.path.join(dpath, file_suffix + ".jpg")
    intrinsics_file = os.path.join(dpath, file_suffix + "_intrinsics.txt")
    # Read the files
    depth = o3d.io.read_image(depth_file)
    color = o3d.io.read_image(color_file)
    #depth = o3d.io.read_image(dpath + 'Animal_box3_u_nano_11_depth.png')
    #color = o3d.io.read_image(dpath + 'Animal_box3_u_nano_11.jpg')
    K = np.loadtxt(intrinsics_file)
      

    camera_intrinsics = o3d.camera.PinholeCameraIntrinsic()
    camera_intrinsics.set_intrinsics(int(K[0]), int(K[1]), K[2], K[3], K[4], K[5])
    
    depth_np = np.asarray(depth)
    if ( depth_np.max() > 20 ) : # Depth is in millimeters
        flying_pixel_filter_threshold = 5000 # 100
        print("Millimeters")
    else : # meters
        flying_pixel_filter_threshold = 0.1 # 0.1
        print("meters")
        #print(flying_pixel_filter_threshold, " -- ", depth_np.max())

    result_mask = numba_eliminate_flying_pixels(depth_np.copy(), ws, 0.001)
    depth_np[result_mask >600000] = 0
    # Re-insert filtered depth into the rgbd image
    

    rgbdc = o3d.geometry.RGBDImage.create_from_color_and_depth(
        color, o3d.geometry.Image(depth_np), depth_trunc=4.0, convert_rgb_to_intensity=False
    )
    #rgbdc.depth = o3d.geometry.Image(depth_np)
    volume = o3d.pipelines.integration.ScalableTSDFVolume(
        voxel_length=4.0 / 512.0, sdf_trunc=0.04, color_type=o3d.pipelines.integration.TSDFVolumeColorType.RGB8
    )
    
    volume.integrate(rgbdc, camera_intrinsics, np.eye(4))
    pcd_tsdf = volume.extract_point_cloud()
    pcd_tsdf.transform(tform)
    
    return pcd_tsdf


# 1,13,15,8,18,21,7

ID = 7
Animal_ID = 'Animal_'+ str(ID)+"_1"
dpath = '/home/vigir3d/Datasets/cattle_scans/Cattle_11_17_22/'+Animal_ID+'/'

pcds = [process_file_list_comp_v2(file_id, dpath, tform) for file_id, tform in zip(file_ids,tforms)]
o3d.visualization.draw_geometries(pcds)

fname = dpath + Animal_ID + '_reg.ply'
combine_write_pcds(pcds,fname)

# %%
fname

# %%
def combine_write_pcds(pcds,fname):
    pcd_comb = o3d.geometry.PointCloud()
    for pcd in pcds:
        pcd_comb+=pcd
    o3d.io.write_point_cloud(fname,pcd_comb)

# %%
o3d.visualization.draw_geometries([pcd_downsampled])

# %%
pcd_ds_5_no_upsamp = copy.deepcopy(pcd_downsampled)
mesh_5_no_upsamp = copy.deepcopy(mesh)

# %%
draw_registration_result(pcd_ds_14_no_upsamp, pcd_downsampled,np.eye(4))

# %%
pcd_ds_14_no_upsamp = copy.deepcopy(pcd_downsampled)
mesh_14_no_upsamp = copy.deepcopy(mesh)

# %%
for p in ptsdf : 
    o3d.visualization.draw_geometries([p])

# %%
o3d.visualization.draw_geometries([ptsdf_all])

# %%
def upsample_using_reference_normals_new(sparse_pcd, dense_pcd, search_radius=0.02, angle_threshold=30):
    # Ensure thae point clouds have normals
    if not sparse_pcd.has_normals():
        sparse_pcd.estimate_normals()
    if not dense_pcd.has_normals():
        dense_pcd.estimate_normals()

    dense_points = np.asarray(dense_pcd.points)
    dense_tree = cKDTree(dense_points)

    sparse_points = np.asarray(sparse_pcd.points)
    sparse_normals = np.asarray(sparse_pcd.normals)
    
    # This retrieves the indices of all neighbors within the search_radius
    neighbor_indices = dense_tree.query_ball_point(sparse_points, search_radius, workers=-1)
    
    valid_indices = []
    for i, idx_row in enumerate(neighbor_indices):
        neighbors = dense_points[idx_row]
        neighbor_normals = np.asarray(dense_pcd.normals)[idx_row]

        # Calculate angles between sparse point's normal and all its neighbors' normals
        angles = np.degrees(np.arccos(np.clip(np.dot(sparse_normals[i], neighbor_normals.T), -1.0, 1.0)))

        # Filtering neighbors based on angle threshold
        valid_neighbor_indices = np.array(idx_row)[angles < angle_threshold]
        valid_indices.extend(valid_neighbor_indices)
#     valid_indices = []
#     for i, idx_row in enumerate(neighbor_indices):
#         neighbors = dense_points[idx_row]
#         neighbor_normals = np.asarray(dense_pcd.normals)[idx_row]
        
#         # Calculate angles between sparse point's normal and all its neighbors' normals
#         angles = np.degrees(np.arccos(np.clip(np.dot(sparse_normals[i], neighbor_normals.T), -1.0, 1.0)))

#         # Filtering neighbors based on angle threshold
#         valid_for_current = idx_row[angles < angle_threshold]
#         valid_indices.extend(valid_for_current)

    unique_valid_indices = np.unique(valid_indices)
    final_valid_neighbors = dense_points[unique_valid_indices]
    
    upsampled_points = np.vstack([sparse_points, final_valid_neighbors])

    upsampled_pcd = o3d.geometry.PointCloud()
    upsampled_pcd.points = o3d.utility.Vector3dVector(upsampled_points)
    upsampled_pcd.estimate_normals()

    return upsampled_pcd

# %%
import subprocess
import time
import copy
import os
def call_cpp_program(directory_path):
    # Adjust this to the path of your compiled C++ executable if it's not in the system's PATH.
    cpp_executable = "/home/vigir3d/Software/programs/k4a-read-mkvs/build/k4a_read_mkv"
    command = cpp_executable + " " + directory_path + "*.mkv"
    print(command)
    # Call the C++ program.
    result = subprocess.run(command, shell=True, check=True)

    # Check if the C++ program executed without errors.
    if result.returncode != 0:
        print(f"Error running {cpp_executable}")
        return False

    return True

def apply_ICP(pcds_tsdf):
    t01 = test_ICP(pcds_tsdf[0],pcds_tsdf[1])
    t12 = test_ICP(pcds_tsdf[1],pcds_tsdf[2])
    t32 = test_ICP(pcds_tsdf[3],pcds_tsdf[2])
    t43 = test_ICP(pcds_tsdf[4],pcds_tsdf[3])
    t52 = test_ICP(pcds_tsdf[5],pcds_tsdf[2])

    h0 = t12@t01
    h1 = t12
    h3 = t32
    h4 = t32@t43
    h5 = t52

    p0 = copy.deepcopy(pcds_tsdf[0]).transform(h0)
    p1 = copy.deepcopy(pcds_tsdf[1]).transform(h1)
    p3 = copy.deepcopy(pcds_tsdf[3]).transform(h3)
    p4 = copy.deepcopy(pcds_tsdf[4]).transform(h4)
    p5 = copy.deepcopy(pcds_tsdf[5]).transform(h5)

    pcd_all = o3d.geometry.PointCloud()
    pcd_all = p0+p1+pcds_tsdf[2]+p3+p4+p5
    return pcd_all

def process_file_list_comp(file_id, dpath,tform=np.eye(4)):
    ws = 2
    flying_pixel_filter_threshold = 1000
    # Format filenames
    dpath = dpath.rstrip('/')

    # Split by the directory separator and get the last part
    suffix = os.path.basename(dpath)
    
    file_suffix = suffix + "_nano_" + str(file_id)
    # Construct full file paths using os.path.join for better cross-platform compatibility
    depth_file = os.path.join(dpath, file_suffix + "_depth.png")
    color_file = os.path.join(dpath, file_suffix + ".jpg")
    intrinsics_file = os.path.join(dpath, file_suffix + "_intrinsics.txt")
    # Read the files
    depth = o3d.io.read_image(depth_file)
    color = o3d.io.read_image(color_file)
    #depth = o3d.io.read_image(dpath + 'Animal_box3_u_nano_11_depth.png')
    #color = o3d.io.read_image(dpath + 'Animal_box3_u_nano_11.jpg')
    K = np.loadtxt(intrinsics_file)
      
    
    camera_intrinsics = o3d.camera.PinholeCameraIntrinsic()
    camera_intrinsics.set_intrinsics(int(K[0]), int(K[1]), K[2], K[3], K[4], K[5])

    rgbdc = o3d.geometry.RGBDImage.create_from_color_and_depth(
        color, depth, depth_trunc=4.0, convert_rgb_to_intensity=False
    )

    volume = o3d.pipelines.integration.ScalableTSDFVolume(
        voxel_length=4.0 / 512.0, sdf_trunc=0.04, color_type=o3d.pipelines.integration.TSDFVolumeColorType.RGB8
    )

    volume.integrate(rgbdc, camera_intrinsics, np.eye(4))
    pcd_tsdf = volume.extract_point_cloud()
    pcd_tsdf.transform(tform)
    
    return pcd_tsdf


if __name__ == "__main__":
    start = time.time()
    #for i in range(10):
    dpath = '/home/vigir3d/Datasets/cattle_scans/Cattle_11_17_22/Animal_13_6/'
    new_dpath = copy.deepcopy(dpath).rstrip('/')

    # Split by the directory separator and get the last part
    suffix = os.path.basename(new_dpath)
    tform_path = '/home/vigir3d/Datasets/cattle_scans/farm_07_28/Animal_calib_new1/'
    tforms = load_calibration(tform_path)
    boxes = False
    if boxes: 
        file_ids = range(11,17)
    else:
        file_ids = [11,12,14,16,17,18]  # exclude head cameras

    # Generate a list of volumes using list comprehension

    #success = call_cpp_program(dpath)
    success = True
    if success: 
        pcds_tsdf_13 = [process_file_list_comp(file_id, dpath,tform) for file_id,tform in zip(file_ids,tforms)]
        #pcd_tmp = apply_ICP(pcds_tsdf)
        #pcds_all = perform_pairwise_alignment(pcds_tsdf)
        #pcds_combined = o3d.geometry.PointCloud()
        #pcds_combined = pcds_tsdf[0]+pcds_tsdf[1]+pcds_tsdf[2]+pcds_tsdf[3]+pcds_tsdf[4]+pcds_tsdf[5]
        #pcds_all.orient_normals_consistent_tangent_plane(30)
        #o3d.visualization.draw_geometries([pcds_all])
        #o3d.visualization.draw_geometries([pcd_tmp])

        #o3d.io.write_point_cloud(dpath+"/"+suffix+".ply", pcds_all)
    end = time.time()
    print("Duration was:", end-start, "s")

# %%
def process_file_list_comp(file_id, dpath,tform):
    
    # Format filenames
    dpath = dpath.rstrip('/')

    # Split by the directory separator and get the last part
    suffix = os.path.basename(dpath)
    
    file_suffix = suffix + "_nano_" + str(file_id)
    # Construct full file paths using os.path.join for better cross-platform compatibility
    depth_file = os.path.join(dpath, file_suffix + "_depth.png")
    color_file = os.path.join(dpath, file_suffix + ".jpg")
    intrinsics_file = os.path.join(dpath, file_suffix + "_intrinsics.txt")
    # Read the files
    depth_orig = o3d.io.read_image(depth_file)
    device = o3d.core.Device('CUDA:0')
    depth_cuda = o3d.t.io.read_image(depth_file).to(device)
    depth_filtered = depth_cuda.filter_b
    color = o3d.io.read_image(color_file)

# %%
o3d.visualization.draw_geometries([pcds_tsdf_13[0]])

# %%
#dpath = dpath.rstrip('/')

# Split by the directory separator and get the last part
#suffix = os.path.basename(dpath)

#file_suffix = suffix + "_nano_" + str(11)
# Construct full file paths using os.path.join for better cross-platform compatibility
#depth_file = os.path.join(dpath, file_suffix + "_depth.png")
#color_file = os.path.join(dpath, file_suffix + ".jpg")
#intrinsics_file = os.path.join(dpath, file_suffix + "_intrinsics.txt")
K = np.loadtxt(intrinsics_file)


camera_intrinsics = o3d.camera.PinholeCameraIntrinsic()
camera_intrinsics.set_intrinsics(int(K[0]), int(K[1]), K[2], K[3], K[4], K[5])

cpu = True

# Read the files
depth_orig = o3d.io.read_image(depth_file)
device = o3d.core.Device('CUDA:0')
depth_cuda = o3d.t.io.read_image(depth_file).to(device)
depth_filtered = depth_cuda.filter_bilateral(7,0.004,0.004)
#color = o3d.io.read_image(color_file)
dp_cpu = depth_filtered.cpu().to_legacy()

plt.subplot(1, 2, 1)
plt.title('orig grayscale image')
plt.imshow(depth_orig)
plt.subplot(1, 2, 2)
plt.title('filtered depth image')
plt.imshow(dp_cpu)
plt.show()
p_orig = o3d.geometry.PointCloud.create_from_depth_image(depth_orig,camera_intrinsics)
p_filtered = o3d.geometry.PointCloud.create_from_depth_image(dp_cpu,camera_intrinsics)

#o3d.visualization.draw_geometries([p_orig])

o3d.visualization.draw_geometries([p_filtered])

# %%
max_d = np.max(np.asarray(depth_orig))
print(max_d)

# %%
a13 = '/home/vigir3d/Datasets/cattle_scans/Cattle_11_17_22/Animal_13_6/'
files = glob.glob(a13+"*.ply")
files.sort()
p1 = o3d.io.read_point_cloud(files[0])

# %%
pcd1 = o3d.io.read_point_cloud("/home/vigir3d/Desktop/animal_482_2_demo_cleaned.ply")

# %%
pcdb1_down = pcd1.voxel_down_sample(voxel_size=0.05)
pcdb1_down.orient_normals_consistent_tangent_plane(30)
o3d.io.write_point_cloud("/home/vigir3d/Desktop/animal_482_2_demo_downsampled.ply",pcdb1_down)

# %%
p0 = o3d.io.read_point_cloud(files[0])
p1 = o3d.io.read_point_cloud(files[1])

p2 = o3d.io.read_point_cloud(files[2])
p3 = o3d.io.read_point_cloud(files[3])

p4 = o3d.io.read_point_cloud(files[4])
p5 = o3d.io.read_point_cloud(files[5])

# %%
draw_registration_result(p1,p2,e01)

# %%
draw_registration_result(pcds_tsdf_13[0], pcds_tsdf_13[1],e01)

# %%
a12,e12 = register_two_views_teaser(p1,p2,0.05)

# %%
a01,b01 = register_two_views_teaser(pcds_tsdf_5[0],pcds_tsdf_5[1],0.025) # 0.069

# %%
a01,b01 = register_two_views_teaser(pcds_tsdf_5[0],pcds_tsdf_5[1],vs) # 0.069
a12,b12 = register_two_views_teaser(pcds_tsdf_5[1],pcds_tsdf_5[2],vs) #0.046 | *0.026
at43,b43 = register_two_views_teaser(pcds_tsdf_5[4],pcds_tsdf_5[3],vs) # *0.028 |  0.06 | 0.084
#0.86
a52,b52 = register_two_views_teaser(pcds_tsdf_5[5],pcds_tsdf_5[2],vs) # *0.05 | 0.044000000000000025 | 0.084
a32,b32 = register_two_views_teaser(pcds_tsdf_5[3],pcds_tsdf_5[2],vs) # *0.031  0.084

# %%
for vs in np.arange(0.02,0.03,0.005)  : #vs = 0.042
    f01,d01 = register_two_views_teaser(pcds_tsdf_2[0],pcds_tsdf_2[1],vs) # 0.069
#f12,d12 = register_two_views_teaser(pcds_tsdf_2[1],pcds_tsdf_2[2],vs) #0.046 | *0.026
#ft43,d43 = register_two_views_teaser(pcds_tsdf_2[4],pcds_tsdf_2[3],vs) # *0.028 |  0.06 | 0.084
#0.86

#f52,d52 = register_two_views_teaser(pcds_tsdf_2[5],pcds_tsdf_2[2],vs) # *0.05 | 0.044000000000000025 | 0.084
#f32,d32 = register_two_views_teaser(pcds_tsdf_2[3],pcds_tsdf_2[2],vs) # *0.031  0.084

# %%
h0 = d12 @ d01
h1 = d12
h3 = d32
h4 = d32@d43
h5 = d52


p0 = copy.deepcopy(pcds_tsdf_2[0]).transform(h0)
p1 = copy.deepcopy(pcds_tsdf_2[1]).transform(h1)
p3 = copy.deepcopy(pcds_tsdf_2[3]).transform(h3)
p4 = copy.deepcopy(pcds_tsdf_2[4]).transform(h4)
p5 = copy.deepcopy(pcds_tsdf_2[5]).transform(h5)

# %%
plist = [pcds_tsdf_2[2],p0,p1,p3,p4,p5]
pcd_all_comb_2 = o3d.geometry.PointCloud()
for i in range(len(plist)):
    print("current Addition: ", i )
    pcd_all_comb_2+=plist[i]
    o3d.visualization.draw_geometries([pcd_all_comb_2])

# %%
#for vs in np.arange(0.02,0.087,0.001):
vs = 0.084

#print(vs)
#for vs in np.arange(0.01, 0.086,0.001):
#t01,r01 = register_two_views_teaser(pcds_tsdf[0],pcds_tsdf[1],vs)
#t12,r12 = register_two_views_teaser(pcds_tsdf[1],pcds_tsdf[2],vs) #0.046
#t43,r43 = register_two_views_teaser(pcds_tsdf[4],pcds_tsdf[3],vs) # 0.06
#0.86
#t52,r52 = register_two_views_teaser(pcds_tsdf[5],pcds_tsdf[2],vs) #0.044000000000000025
#t32,r32 = register_two_views_teaser(pcds_tsdf[3],pcds_tsdf[2],vs) # 0.084

# sticth the others together and then add 0
h0 = r12 @ r01
h1 = r12
h3 = r32
h4 = r32@r43
h5 = r52


p0 = copy.deepcopy(pcds_tsdf[0]).transform(h0)

p1 = copy.deepcopy(pcds_tsdf[1]).transform(h1)

p3 = copy.deepcopy(pcds_tsdf[3]).transform(h3)
p4 = copy.deepcopy(pcds_tsdf[4]).transform(h4)
p5 = copy.deepcopy(pcds_tsdf[5]).transform(h5)

o3d.visualization.draw_geometries([p0, p1,p3,p4,p5,pcds_tsdf[2]])

# %%
o3d.visualization.draw_geometries([p1,p3,p4,p5])

# %%
t02 = demo_manual_registration(pcomb,pcds_tsdf[0])

# %%
for vs in np.arange(0.01,0.05,0.01):
    print(vs)
    t02,r02 = register_two_views_teaser(pcds_tsdf[1],pcds_tsdf[0], vs)

# %%
for vs in np.arange(0.02, 0.08,0.01):
    print("*****VS ::: ********* : ", vs)
    t02,r02 = register_two_views_teaser(pcomb_down,pcds_tsdf[0], vs)

# %%
o3d.visualization.draw_geometries([pcomb])

# %%
o3d.visualization.draw_geometries([p1,p3,p4, p5,pcds_tsdf[2]])
pcomb = o3d.geometry.PointCloud()
pcomb = p1+p3+p4+p5+pcds_tsdf[2]

# %%
dpath = '/home/vigir3d/Datasets/cattle_scans/farm_07_28/Animal_cyl1/'
pcds_tsdf_cyl = [process_file_list_comp(file_id, dpath,tform) for file_id,tform in zip(file_ids,tforms)]

# %%
o3d.visualization.draw_geometries(pcds_tsdf_cyl)

# %%
dpath = '/home/vigir3d/Datasets/cattle_scans/farm_07_28/Animal_b1/'
dpath = dpath.rstrip('/')

# Split by the directory separator and get the last part
suffix = os.path.basename(dpath)
print(suffix)

# %%
def colored_ICP_N(source, target):
    
    voxel_radius = [0.04, 0.02, 0.01]
    max_iter = [50, 30, 14]
    current_transformation = np.identity(4)
    #print("3. Colored point cloud registration")
    for scale in range(3):
        iters = max_iter[scale]
        radius = voxel_radius[scale]
        #print("iteration: ", iters, radius, scale)

        #print("3-1. Downsample with a voxel size %.2f" % radius)
        source_down = copy.deepcopy(source).voxel_down_sample(radius)
        target_down = copy.deepcopy(target).voxel_down_sample(radius)

        #print("3-2. Estimate normal.")
        source_down.estimate_normals(
            o3d.geometry.KDTreeSearchParamHybrid(radius=radius * 2, max_nn=30))
        target_down.estimate_normals(
            o3d.geometry.KDTreeSearchParamHybrid(radius=radius * 2, max_nn=30))

        #print("3-3. Applying colored point cloud registration")
        result_icp = o3d.pipelines.registration.registration_colored_icp(
            source_down, target_down, radius, current_transformation,
            o3d.pipelines.registration.TransformationEstimationForColoredICP(),
            o3d.pipelines.registration.ICPConvergenceCriteria(relative_fitness=1e-6,
                                                              relative_rmse=1e-6,
                                                              max_iteration=iters))
        current_transformation = result_icp.transformation
    
   
        #draw_registration_result(source, target, current_transformation)
    return current_transformation

# %%
t01 = colored_ICP(pcds_tsdf[1],pcds_tsdf[2])
draw_registration_result(pcds_tsdf[1],pcds_tsdf[2],t01)

# %%
ptsdf_all = o3d.geometry.PointCloud()
ptsdf_all = pcds_tsdf[0]+pcds_tsdf[1]+pcds_tsdf[2]+pcds_tsdf[3]+pcds_tsdf[4]+pcds_tsdf[5]

# %%
o3d.visualization.draw_geometries(pcds_tsdf_cyl)

# %%
draw_registration_result(ptsdf_all,pcd_all,np.eye(4))

# %%
h0 = t12@t01
h1 = t01
h3 = t32
h4 = t52@t45
h5 = t52

pc0 = copy.deepcopy(pcds_tsdf[0]).transform(h0)
pc1 = copy.deepcopy(pcds_tsdf[1]).transform(h1)
pc3 = copy.deepcopy(pcds_tsdf[3]).transform(h3)
pc4 = copy.deepcopy(pcds_tsdf[4]).transform(h4)
pc5 = copy.deepcopy(pcds_tsdf[5]).transform(h5)

o3d.visualization.draw_geometries([pc0,pc1,pcds_tsdf[2],pc4,pc5])

# %%
t43 = demo_manual_registration(pcds_tsdf[4],pcds_tsdf[3])

# %%
#draw_registration_result(pcds_tsdf_cyl[4],pcds_tsdf_cyl[3],t43)
#draw_registration_result(pcds_tsdf_cyl[0],pcds_tsdf_cyl[1],t01)
draw_registration_result(pcds_tsdf_cyl[1],pcds_tsdf_cyl[2],t12)

# %%
t12 = demo_manual_registration(pcds_tsdf[1],pcds_tsdf[2])

# %%
boxes = pcds_tsdf

# %%
def colored_ICP(source, target):
    #draw_registration_result(source, target, np.eye(4))
    voxel_radius = [0.04, 0.02, 0.01]
    max_iter = [50, 30, 14]
    current_transformation = np.identity(4)
    print("3. Colored point cloud registration")
    for scale in range(3):
        iters = max_iter[scale]
        radius = voxel_radius[scale]
        print("iteration: ", iters, radius, scale)

        print("3-1. Downsample with a voxel size %.2f" % radius)
        source_down = copy.deepcopy(source).voxel_down_sample(radius)
        target_down = copy.deepcopy(target).voxel_down_sample(radius)

        print("3-2. Estimate normal.")
        source_down.estimate_normals(
            o3d.geometry.KDTreeSearchParamHybrid(radius=radius * 2, max_nn=30))
        target_down.estimate_normals(
            o3d.geometry.KDTreeSearchParamHybrid(radius=radius * 2, max_nn=30))

        print("3-3. Applying colored point cloud registration")
        result_icp = o3d.pipelines.registration.registration_colored_icp(
            source_down, target_down, radius, current_transformation,
            o3d.pipelines.registration.TransformationEstimationForColoredICP(),
            o3d.pipelines.registration.ICPConvergenceCriteria(relative_fitness=1e-6,
                                                              relative_rmse=1e-6,
                                                              max_iteration=iters))
        current_transformation = result_icp.transformation
    
    return current_transformation

# %%
o3d.visualization.draw_geometries([boxes[5],boxes[2]])

# %%
t52 = test_ICP(boxes[5],boxes[2])
draw_registration_result(boxes[5],boxes[2],t52)

# %%
h02 = t12@t01
h12 = t12
h32 = t32
h42 = t32@t43
h52 = t52

p0 = copy.deepcopy(boxes[0]).transform(h02)
p1 = copy.deepcopy(boxes[1]).transform(h12)
p3 = copy.deepcopy(boxes[3]).transform(h32)
p4 = copy.deepcopy(boxes[4]).transform(h42)
p5 = copy.deepcopy(boxes[5]).transform(h52)

# %%
c0 = copy.deepcopy(pcds_tsdf_cyl[0]).transform(h02)
c1 = copy.deepcopy(pcds_tsdf_cyl[1]).transform(h12)
c3 = copy.deepcopy(pcds_tsdf_cyl[3]).transform(h32)
c4 = copy.deepcopy(pcds_tsdf_cyl[4]).transform(h42)
c5 = copy.deepcopy(pcds_tsdf_cyl[5]).transform(h52)
o3d.visualization.draw_geometries([c0,c1,c3,c4,c5])
#o3d.visualization.draw_geometries(pcds_tsdf_cyl)

# %%
pcd_no_5 = o3d.geometry.PointCloud()
pcd_no_5 = p0+p1+p3+p4+boxes[2]

r52 = register_two_views_teaser(pcd_no_5,boxes[5],0.045)

# %%
o3d.visualization.draw_geometries([p0,p1,p3,p4,boxes[2]])

# %%
for vs in np.arange(0.04, 0.07,0.001):
    r50, t50 = register_two_views_teaser(boxes[5],boxes[3],vs)

# %%
# for farm_07_28 Animal_c1
#t01 = colored_ICP(boxes[0],boxes[1])
#draw_registration_result(boxes[0],boxes[1],t01)
#t12 = colored_ICP(boxes[1],boxes[2])
#draw_registration_result(boxes[1],boxes[2],t12)
#r32, t32 = register_two_views_teaser(boxes[3],boxes[2],vs) # 0.047
#draw_registration_result(boxes[3],boxes[2],t32)
#r43, t43 = register_two_views_teaser(boxes[4],boxes[3],vs) # 0.025
#draw_registration_result(boxes[4],boxes[3],t43)
#r52, t52 = test_ICP(boxes[5],boxes[4])
#draw_registration_result(boxes[5],boxes[2],t52)

# %%
tpath = '/home/vigir3d/Software/programs/Cattle_Scanner/'
h02 = np.loadtxt(tpath+'c_icp_0_2.txt')
h12 = np.loadtxt(tpath+ 'c_icp_1_2.txt')
h32 = np.loadtxt(tpath+ 'c_icp_3_2.txt')
h42 = np.loadtxt(tpath+ 'c_icp_4_2.txt')
h52 = np.loadtxt(tpath+ 'c_icp_5_2.txt')

# %%
p0 = copy.deepcopy(pcds_tsdf[0]).transform(h02)
p1 = copy.deepcopy(pcds_tsdf[1]).transform(h12)
p3 = copy.deepcopy(pcds_tsdf[3]).transform(h32)
p4 = copy.deepcopy(pcds_tsdf[4]).transform(h42)
p5 = copy.deepcopy(pcds_tsdf[5]).transform(h52)

# %%
o3d.visualization.draw_geometries([p0,p1,p3,p4,p5])

# %%
t52 = demo_manual_registration(pcds_tsdf[5],pcds_tsdf[2])
#r52, t52 = register_two_views_teaser(pcds_tsdf[5],pcds_tsdf[2],vs) #0.03900000000000002

# %%
#for vs in np.arange(0.06,0.09,0.005) : #vs = 0.035
 #   print(vs)
#for vs in np.arange(0.02,0.08,0.001): #vs = 0.095
#   print("Current VS : ", vs)
#r01, t01 = register_two_views_teaser(pcds_tsdf[0],pcds_tsdf[1],vs)# 0.035
#r12, t12 = register_two_views_teaser(pcds_tsdf[1],pcds_tsdf[2],vs) # 0.065
#r32, t32 = register_two_views_teaser(pcds_tsdf[3],pcds_tsdf[2],vs) # 0.075
#r45, t45 = register_two_views_teaser(pcds_tsdf[4],pcds_tsdf[5],vs)
vs =0.039
r52, t52 = register_two_views_teaser(pcds_tsdf[5],pcds_tsdf[2],vs) #0.03900000000000002

# %%
t01 = test_ICP(pcds_tsdf[0],pcds_tsdf[1])
t12 = test_ICP(pcds_tsdf[1],pcds_tsdf[2])
t32 = test_ICP(pcds_tsdf[3],pcds_tsdf[2])
t43 = test_ICP(pcds_tsdf[4],pcds_tsdf[3])
t52 = test_ICP(pcds_tsdf[5],pcds_tsdf[2])

h0 = t12@t01
h1 = t12
h3 = t32
h4 = t32@t43
h5 = t52

p0 = copy.deepcopy(pcds_tsdf[0]).transform(h0)
p1 = copy.deepcopy(pcds_tsdf[1]).transform(h1)
p3 = copy.deepcopy(pcds_tsdf[3]).transform(h3)
p4 = copy.deepcopy(pcds_tsdf[4]).transform(h4)
p5 = copy.deepcopy(pcds_tsdf[5]).transform(h5)

pcd_all = o3d.geometry.PointCloud()
pcd_all = p0+p1+pcds_tsdf[2]+p3+p4+p5

# %%
def draw_registration_result(source, target, transformation):
    source_temp = copy.deepcopy(source)
    target_temp = copy.deepcopy(target)
    source_temp.paint_uniform_color([1, 0.706, 0])
    target_temp.paint_uniform_color([0, 0.651, 0.929])
    source_temp.transform(transformation)
    o3d.visualization.draw_geometries([source_temp, target_temp])


def pick_points(pcd):
    print("")
    print(
        "1) Please pick at least three correspondences using [shift + left click]"
    )
    print("   Press [shift + right click] to undo point picking")
    print("2) After picking points, press 'Q' to close the window")
    vis = o3d.visualization.VisualizerWithEditing()
    vis.create_window()
    vis.add_geometry(pcd)
    vis.run()  # user picks points
    vis.destroy_window()
    print("")
    return vis.get_picked_points()


def demo_manual_registration(src, tgt):
    print("Demo for manual ICP")
    source = src
    target = tgt
    print("Visualization of two point clouds before manual alignment")
    draw_registration_result(source, target, np.identity(4))

    # pick points from two point clouds and builds correspondences
    picked_id_source = pick_points(source)
    picked_id_target = pick_points(target)
    assert (len(picked_id_source) >= 3 and len(picked_id_target) >= 3)
    assert (len(picked_id_source) == len(picked_id_target))
    corr = np.zeros((len(picked_id_source), 2))
    corr[:, 0] = picked_id_source
    corr[:, 1] = picked_id_target

    # estimate rough transformation using correspondences
    print("Compute a rough transform using the correspondences given by user")
    p2p = o3d.pipelines.registration.TransformationEstimationPointToPoint()
    trans_init = p2p.compute_transformation(source, target,
                                            o3d.utility.Vector2iVector(corr))

    # point-to-point ICP for refinement
    print("Perform point-to-point ICP refinement")
    threshold = 0.03  # 3cm distance threshold
    reg_p2p = o3d.pipelines.registration.registration_icp(
        source, target, threshold, trans_init,
        o3d.pipelines.registration.TransformationEstimationPointToPoint())
    draw_registration_result(source, target, reg_p2p.transformation)
    return reg_p2p.transformation
    print("")

# %%
o3d.visualization.draw_geometries([pcd_all])

# %%
def test_ICP(src,tgt):
    threshold = 0.005
    #print("Apply point-to-point ICP")
    reg_p2p = o3d.pipelines.registration.registration_icp(
        src, tgt, threshold, np.eye(4),
        o3d.pipelines.registration.TransformationEstimationPointToPoint())
    #print(reg_p2p)
    #print("Transformation is:")
    #print(reg_p2p.transformation)
    
    #draw_registration_result(src, tgt, reg_p2p.transformation)
    return reg_p2p.transformation

# %%
t01 = colored_ICP(pcds_tsdf[0],pcds_tsdf[1])

# %%
draw_registration_result(pcds_tsdf[0],pcds_tsdf[1],np.eye(4))

# %%
o3d.visualization.draw_geometries([pcds_tsdf[0]])

# %%
t12,r12 = register_two_views_teaser(pcds_tsdf[1],pcds_tsdf[2],0.03)

# %%
t32,r32 = register_two_views_teaser(pcds_tsdf[4],pcds_tsdf[5],0.05)

# %%
cv2.imwrite()

# %%
def segment_images_paper(depth_image_array, rgb_image_array,datpath):
    #depth_image_array = np.asarray(last_frame.depth)
    print("Pre:",np.max(depth_image_array), " -- ", np.min(depth_image_array))
    depth_PIL = Image.fromarray(depth_image_array).convert("RGB")
    rgb_PIL = Image.fromarray(rgb_image_array)

    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    rgb_mask = get_model_mask(model_rgb, rgb_PIL)
    depth_mask = get_model_mask(model_depth, depth_PIL)
   
    rgb_mask_np = rgb_mask.cpu().numpy().squeeze(0)
    depth_mask_np = depth_mask.cpu().numpy().squeeze(0)

    rgb_mask_np = (rgb_mask_np * 255).astype(np.uint8)
    depth_mask_np = (depth_mask_np * 255).astype(np.uint8)

    cv2.imwrite(datpath+"rgb_mask.png", rgb_mask_np)
    cv2.imwrite(datpath+"depth_mask.png", depth_mask_np)

    # ... rest of your code ...

    # Check if depth_mask is empty, if so use rgb_mask
    if depth_mask.nelement() == 0:
        mask_combined = rgb_mask
    else:
        mask_combined = depth_mask | rgb_mask  # 1 vote arbitration (OR the masks)

    # Convert tensor to numpy array and ensure the right datatype
    mask_combined_np = mask_combined.cpu().numpy().squeeze(0)  # Convert to NumPy and remove extra dimensions
    mask_combined_np = (mask_combined_np * 255).astype(np.uint8)  # Scale to 8-bit if necessary

    # Save the combined mask
    cv2.imwrite(datpath + "combined_mask.png", mask_combined_np)

    # Process RGB image
    mask_image = mask_combined_np[..., None]  # Add a channel dimension if necessary
    fg_image_rgb = rgb_image_array * mask_image
    fg_image_rgb_bgr = cv2.cvtColor(fg_image_rgb, cv2.COLOR_RGB2BGR)  # Convert to BGR for OpenCV

    # Save the RGB image
    cv2.imwrite(datpath + "fg_color.png", fg_image_rgb_bgr)

    # Process Depth image
    squeezed_mask = np.squeeze(mask_image)  # Remove channel dimension if necessary
    fg_image_depth = (depth_image_array * squeezed_mask) * 1000  # Upscale

    # Save the depth image
    cv2.imwrite(datpath + "fg_depth.png", fg_image_depth)

# %%
datpath = '/home/vigir3d/Datasets/cattle_scans/farm_scan1/Animal_482_2/anima_482_12/'

# %%
color = o3d.io.read_image(datpath+'/color/00011.jpg')
depth = o3d.io.read_image(datpath+'/depth/00011.png')

# %%
c = np.asarray(color)
d = np.asarray(depth)

# %%
segment_images_paper(d,c,datpath)
